# %% [markdown]
# ### Notebook décrivant la fusion des données pour la régression des facteurs estimés

# %%
#environnement


import pandas as pd

import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import datetime
import os

# %% [markdown]
# ### Etude des données de Nick Bloom

# %%
###Récupérer données Nick Bloom:

# Load the Excel file
file_path = 'data_regression/Europe_Policy_Uncertainty_Data (1).xlsx'
data_NB = pd.read_excel(file_path, engine='openpyxl')
print(data_NB.tail())

# Drop the last line of the data
data_NB = data_NB[:-1]
# Print the last value of the column "Year"
print("Last year in the data:", data_NB['Year'].iloc[-1])

# Create a new column that indicates the date of each line as the first day of each month
data_NB['Date'] = pd.to_datetime(data_NB[['Year', 'Month']].assign(DAY=1))

data_NB.set_index('Date', inplace=True)

print("DOnnées NB brutes")
print(data_NB.head())
# Out:
#                                                   Year  Month  \
# 453                                               2024   10.0
# 454                                               2024   11.0
# 455                                               2024   12.0
# 456                                               2025    1.0
# 457  Source: 'Measuring Economic Policy Uncertainty...    NaN
#
#      European_News_Index  Germany_News_Index  Italy_News_Index  UK_News_Index  \
# 453           392.077152          871.019902        100.498001     388.310662
# 454           479.988726         1095.932766        124.806529     396.505948
# 455           484.420012          984.385100        133.739942     409.251621
# 456           463.534694          942.147182         98.461246     458.899347
# 457                  NaN                 NaN               NaN            NaN
#
#      France_News_Index  Spain_News_Index
# 453         322.289241        143.935673
# 454         486.844264        124.524185
# 455         567.708852        208.087094
# 456         563.138944        158.013034
# 457                NaN               NaN

# %% [markdown]
# Maintenant qu'on a récupéré les données mesurant l'instabilité politique, on étudie la stationnarité et l'autocorrélation de la série temporelle à partir de 2010 (dates des autres variables:
# Min date: 2010-04-01 00:00:00
# Max date: 2024-12-01 00:00:00).
#
#
# On obtient des données peu autocorrélées pour la France (0.55), pour laquelle on peut rejetter l'hypothèse de non stationarité avec une grande confiance. Pas besoin donc ici de prendre les différences premières

# %%
#calcul de l'autoccorrélation des données de Nick Bloom

data_NB_copy = data_NB[data_NB.index >=np.datetime64("2010-01-01")].copy()
autocorrelations = data_NB_copy.apply(lambda col: col.autocorr() if col.dtype in [np.float64, np.int64] else None)

# Print autocorrelation values
print("Autocorrelation données brutes NB post 2010:")
print(autocorrelations)
# Out:
# Autocorrelation of factors:
# Year                        NaN
# Month                  0.538462
# European_News_Index    0.776889
# Germany_News_Index     0.916924
# Italy_News_Index       0.536853
# UK_News_Index          0.724163
# France_News_Index      0.556503
# Spain_News_Index       0.349930
# dtype: float64

# %%
#étude de la stationnarité des données de Nick Bloom

#conduct a test of stationarity on the factors:
from statsmodels.tsa.stattools import adfuller

for column in data_NB_copy.columns:
    print(f"Testing stationarity for {column}:")
    result = adfuller(data_NB_copy[column])
    print(f"p-value for {column}: {result[1]}")
    print("-" * 50)
# Out:
# Testing stationarity for Year:
# p-value for Year: 0.9363133189857433
# --------------------------------------------------
# Testing stationarity for Month:
# p-value for Month: 0.0
# --------------------------------------------------
# Testing stationarity for European_News_Index:
# p-value for European_News_Index: 0.5545263051331276
# --------------------------------------------------
# Testing stationarity for Germany_News_Index:
# p-value for Germany_News_Index: 0.9734523285792774
# --------------------------------------------------
# Testing stationarity for Italy_News_Index:
# p-value for Italy_News_Index: 5.249630075815198e-05
# --------------------------------------------------
# Testing stationarity for UK_News_Index:
# p-value for UK_News_Index: 0.05169048535212092
# --------------------------------------------------
# Testing stationarity for France_News_Index:
# p-value for France_News_Index: 3.3448868087884857e-09
# --------------------------------------------------
# Testing stationarity for Spain_News_Index:
# p-value for Spain_News_Index: 1.5521189179358246e-15
# --------------------------------------------------

# %%
#on finit par normaliser l'indice de Nick Bloom pour que ses valeurs soient entre 0 et 1 de manière à faciliter l'interprétation de la régression

data_NB["France_News_Index"]=data_NB["France_News_Index"]/max(data_NB["France_News_Index"])

# %% [markdown]
# ### Etude des facteurs

# %%
###Récupérer Facteurs:


# Lire les données depuis le fichier texte
array_factors = np.loadtxt('data_regression/mu_dd_CANFCPv2_FS10_31.txt')

# Vérifier la forme des données
print("Forme des données :", array_factors.shape)  # Doit afficher (nombre_de_lignes, 10)

# Créer la variable temps sous forme de dates
start_date = datetime.date(2007, 1, 3)
dates = np.array([start_date + datetime.timedelta(weeks=i) for i in range(array_factors.shape[0])])

# Convertir les dates en indices pour la régression linéaire
temps = np.arange(array_factors.shape[0]).reshape(-1, 1)  # [0, 1, 2, ..., n-1]

data_factors=pd.DataFrame(array_factors)
data_factors['Date']= dates
data_factors['Date']=pd.to_datetime(data_factors['Date'])

data_factors.set_index('Date', inplace=True)

data_factors.columns = [f"factor {i+1}" for i in range(10)]



print(data_factors.head())


#scaler les valeurs des facteurs (*100):

data_factors.iloc[:,:] = data_factors.iloc[:,:] * 100

## reindexer pour avoir des facteurs mensuels:

data_factors_mensuel = data_factors.resample('MS').mean()

print("monthly data")
print(data_factors_mensuel.tail())


### Ici on étudie les données utilisées plus tard pour les régressions:

#data_factors_copy2 est utilisé pour étudier les facteurs
data_factors_copy2=data_factors_mensuel[data_factors_mensuel.index>=np.datetime64("2009-12-01")]
# Calculate autocorrelation for each factor
autocorrelations = data_factors_copy2.apply(lambda col: col.autocorr() if col.dtype in [np.float64, np.int64] else None)



import seaborn as sns
# Calculate the cross-correlation matrix
correlation_matrix = data_factors_copy2.corr()

# Plot the cross-correlation matrix of factors
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Cross-Correlation Matrix of Factors")
plt.show()
# Out:
# Forme des données : (924, 10)
#             factor 1  factor 2  factor 3  factor 4  factor 5  factor 6  \
# Date
# 2007-01-03  0.037039  0.038993  0.037558  0.035665  0.034280  0.033354
# 2007-01-10  0.037892  0.039719  0.038157  0.036410  0.034866  0.033904
# 2007-01-17  0.038122  0.039644  0.038197  0.037140  0.035543  0.033932
# 2007-01-24  0.038143  0.039481  0.038021  0.037002  0.035261  0.033325
# 2007-01-31  0.038668  0.039800  0.037851  0.037035  0.036100  0.034062
#
#             factor 7  factor 8  factor 9  factor 10
# Date
# 2007-01-03  0.032688  0.027748  0.023478   0.029683
# 2007-01-10  0.033995  0.028913  0.023632   0.030361
# 2007-01-17  0.034354  0.029508  0.023600   0.030247
# 2007-01-24  0.033655  0.029092  0.023517   0.029767
# 2007-01-31  0.034212  0.029708  0.023751   0.030343
# monthly data
#             factor 1  factor 2  factor 3  factor 4  factor 5  factor 6  \
# Date
# 2024-05-01  4.685066  3.284303  1.646417  2.631871  3.134776  0.187240
# 2024-06-01  4.594397  3.223359  1.729716  2.746980  3.089536  0.314030
# 2024-07-01  4.614542  3.050871  1.349081  2.652789  3.149746  0.272270
# 2024-08-01  4.526080  2.579160  0.722397  2.584113  3.076281  0.020249
# 2024-09-01  4.477882  2.427793  0.514966  2.542936  3.036207 -0.073319
#
#             factor 7  factor 8  factor 9  factor 10
# Date
# 2024-05-01  3.355463  4.151631 -2.103642   6.093354
# 2024-06-01  3.459300  3.821745 -2.177031   6.571534
# 2024-07-01  3.602697  3.924727 -2.346739   6.709139
# 2024-08-01  3.665668  3.845875 -2.526751   6.997456
# 2024-09-01  3.758639  3.800594 -2.682128   7.188458

# %%
# Calculate autocorrelation for each factor
autocorrelations = data_factors_copy2.apply(lambda col: col.autocorr() if col.dtype in [np.float64, np.int64] else None)

# Print autocorrelation values
print("Autocorrelation of factors:")
print(autocorrelations)


# Plot the factors
plt.figure(figsize=(12, 8))
for i, column in enumerate(data_factors_copy2.columns, 1):
    plt.subplot(5, 2, i)
    plt.plot(data_factors_copy2[column])
    plt.title(column)
    plt.xlabel("Date")
    plt.ylabel("Value")
    plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Autocorrelation of factors:
# factor 1     0.993556
# factor 2     0.991196
# factor 3     0.967720
# factor 4     0.975745
# factor 5     0.985238
# factor 6     0.988324
# factor 7     0.984667
# factor 8     0.981007
# factor 9     0.989488
# factor 10    0.993290
# dtype: float64

# %% [markdown]
# On teste ensuite la stationarité. On ne peut pas rejeter l'hypothèse de non stationarité pour la grande majorité des facteurs

# %%
#conduct a test of stationarity on the factors:
from statsmodels.tsa.stattools import adfuller

for column in data_factors_copy2.columns:
    print(f"Testing stationarity for {column}:")
    result = adfuller(data_factors_copy2[column])
    print(f"p-value for {column}: {result[1]}")
    print("-" * 50)
# Out:
# Testing stationarity for factor 1:
# p-value for factor 1: 0.9560167186266483
# --------------------------------------------------
# Testing stationarity for factor 2:
# p-value for factor 2: 0.2876697070943259
# --------------------------------------------------
# Testing stationarity for factor 3:
# p-value for factor 3: 0.24398706911046825
# --------------------------------------------------
# Testing stationarity for factor 4:
# p-value for factor 4: 0.461777300384804
# --------------------------------------------------
# Testing stationarity for factor 5:
# p-value for factor 5: 0.19403962196695662
# --------------------------------------------------
# Testing stationarity for factor 6:
# p-value for factor 6: 0.11275712903239937
# --------------------------------------------------
# Testing stationarity for factor 7:
# p-value for factor 7: 0.2520848429695014
# --------------------------------------------------
# Testing stationarity for factor 8:
# p-value for factor 8: 0.3556666520309036
# --------------------------------------------------
# Testing stationarity for factor 9:
# p-value for factor 9: 0.009041288179547958
# --------------------------------------------------
# Testing stationarity for factor 10:
# p-value for factor 10: 0.10433810755703171
# --------------------------------------------------

# %% [markdown]
# On décide donc d'étudier les premières différences des facteurs, qui devraient être stationnaires

# %%
data_factors_diff=data_factors_copy2.diff().dropna()
# Conduct a test of stationarity on each factor after differencing
for column in data_factors_diff.columns:
    print(f"Testing stationarity for {column} after differencing:")
    result = adfuller(data_factors_diff[column])
    print(f"p-value for {column}: {result[1]}")
    print("-" * 50)
# Out:
# Testing stationarity for factor 1 after differencing:
# p-value for factor 1: 2.687117770166802e-11
# --------------------------------------------------
# Testing stationarity for factor 2 after differencing:
# p-value for factor 2: 0.0008069725189605047
# --------------------------------------------------
# Testing stationarity for factor 3 after differencing:
# p-value for factor 3: 0.009623205216250706
# --------------------------------------------------
# Testing stationarity for factor 4 after differencing:
# p-value for factor 4: 2.4141507878359106e-16
# --------------------------------------------------
# Testing stationarity for factor 5 after differencing:
# p-value for factor 5: 0.00016954848018510264
# --------------------------------------------------
# Testing stationarity for factor 6 after differencing:
# p-value for factor 6: 7.36179621672972e-07
# --------------------------------------------------
# Testing stationarity for factor 7 after differencing:
# p-value for factor 7: 5.269595876032945e-06
# --------------------------------------------------
# Testing stationarity for factor 8 after differencing:
# p-value for factor 8: 1.2765058388951876e-14
# --------------------------------------------------
# Testing stationarity for factor 9 after differencing:
# p-value for factor 9: 0.0009651595084588236
# --------------------------------------------------
# Testing stationarity for factor 10 after differencing:
# p-value for factor 10: 0.001033926990545085
# --------------------------------------------------

# %%
#plot the factors after differencing:
plt.figure(figsize=(12, 8))
for i, column in enumerate(data_factors_diff.columns, 1):
    plt.subplot(5, 2, i)
    plt.plot(data_factors_diff[column])
    plt.title(f"Diff {column}")
    plt.xlabel("Date")
    plt.ylabel("Value")
    plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#On vérifie ensuite si les facteurs différenciés sont autocorrélés:
for column in data_factors_diff.columns:
    autocorr = data_factors_diff[column].autocorr()
    print(f"{column}: {autocorr}")
# Out:
# factor 1: 0.5138199287623739
# factor 2: 0.4253095005795711
# factor 3: 0.23607206709962641
# factor 4: 0.3110252666049042
# factor 5: 0.16545258822244385
# factor 6: 0.4682545962165976
# factor 7: 0.42738077740675273
# factor 8: 0.3765055046932336
# factor 9: 0.701001269801801
# factor 10: 0.6943803080511595

# %%
#on produit enfin une table qui résume les données de data_factors_diff en indiquant leur autocorrélation et leurs statistique de Dickey Fuller:
from tabulate import tabulate
from statsmodels.tsa.stattools import adfuller
# Compute summary statistics
summary_factors_diff = data_factors_diff.copy()
summary_stats_factors_diff = summary_factors_diff.describe().T

# Add autocorrelation column
summary_stats_factors_diff['autocorrelation'] = summary_factors_diff.apply(
    lambda col: col.autocorr() if col.dtype in [np.float64, np.int64] else None, axis=0
)

# Add Dickey-Fuller test p-value column
summary_stats_factors_diff['dickey_fuller_pvalue'] = summary_factors_diff.apply(
    lambda col: adfuller(col)[1] if col.dtype in [np.float64, np.int64] else None, axis=0
)

# Format for markdown or text reports
formatted_table_factordiff = tabulate(summary_factors_diff, headers="keys", tablefmt="github")

print(summary_stats_factors_diff.to_latex(index=True, float_format="%.3f", caption="Summary Statistics with Autocorrelation and Dickey-Fuller Test"))
# Out:
# \begin{table}
# \caption{Summary Statistics with Autocorrelation and Dickey-Fuller Test}
# \begin{tabular}{lrrrrrrrrrr}
# \toprule
#  & count & mean & std & min & 25% & 50% & 75% & max & autocorrelation & dickey_fuller_pvalue \\
# \midrule
# factor 1 & 177.000 & 0.022 & 0.175 & -0.693 & -0.062 & 0.004 & 0.095 & 0.618 & 0.514 & 0.000 \\
# factor 2 & 177.000 & 0.010 & 0.181 & -0.959 & -0.063 & 0.000 & 0.066 & 1.139 & 0.425 & 0.001 \\
# factor 3 & 177.000 & -0.003 & 0.285 & -1.291 & -0.123 & -0.010 & 0.121 & 0.968 & 0.236 & 0.010 \\
# factor 4 & 177.000 & -0.002 & 0.244 & -0.682 & -0.157 & 0.004 & 0.148 & 0.923 & 0.311 & 0.000 \\
# factor 5 & 177.000 & -0.006 & 0.295 & -1.318 & -0.174 & -0.006 & 0.138 & 0.928 & 0.165 & 0.000 \\
# factor 6 & 177.000 & -0.020 & 0.324 & -0.839 & -0.227 & -0.018 & 0.181 & 0.818 & 0.468 & 0.000 \\
# factor 7 & 177.000 & -0.014 & 0.337 & -1.105 & -0.189 & -0.034 & 0.172 & 0.940 & 0.427 & 0.000 \\
# factor 8 & 177.000 & 0.003 & 0.392 & -1.102 & -0.247 & -0.034 & 0.201 & 1.644 & 0.377 & 0.000 \\
# factor 9 & 177.000 & -0.038 & 0.409 & -1.127 & -0.316 & -0.059 & 0.230 & 1.191 & 0.701 & 0.001 \\
# factor 10 & 177.000 & 0.039 & 0.326 & -1.159 & -0.105 & 0.062 & 0.252 & 0.794 & 0.694 & 0.001 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ### Etude des données macroéconomiques

# %%
### Récupérer des données types BCE:

def récup_données_bce(file_path, value_name):
    """
    Cette fonction lit un fichier CSV contenant des données de la BCE et renvoie un DataFrame avec les données pertinentes.
    """
    # Lire le fichier CSV
    data_name = pd.read_csv(file_path)
    print(f"reading {value_name} file")
    
    # Convertir la colonne 'Date' en datetime
    data_name['DATE'] = pd.to_datetime(data_name['DATE'])
    
    # Renommer les colonnes pertinentes
    data_name.columns=['Date',"Time_period",value_name]

    data_name.drop("Time_period", axis=1, inplace=True)

    data_name.set_index('Date', inplace=True)


    
    return data_name


# extraction des données brutes:

file_names = ["20250319150056.csv","inflation_fr.csv","inflationexpect_lt.csv", "euribor3months.csv", "debt_gdp_france.csv"]

list_filepaths= ["data_regression/ECB Data Portal_"+ file for file in file_names]
list_value_names=["deposit_rate", "infl_fr","infl_for_lt","euribor3","debt_gdp_fr"]

list_BCE_data = [récup_données_bce(list_filepaths[i],list_value_names[i]) for i in range(len(list_filepaths))]

for data in list_BCE_data:
    print(data.head())
# Out:
# reading deposit_rate file
# reading infl_fr file
# reading infl_for_lt file
# reading euribor3 file
# reading debt_gdp_fr file
#             deposit_rate
# Date
# 1999-01-01           NaN
# 1999-01-04          0.75
# 1999-01-05          0.75
# 1999-01-06          0.75
# 1999-01-07          0.75
#             infl_fr
# Date
# 1997-01-31      1.8
# 1997-02-28      1.7
# 1997-03-31      1.1
# 1997-04-30      1.0
# 1997-05-31      0.9
#             infl_for_lt
# Date
# 1999-03-31         1.86
# 2000-03-31         1.77
# 2001-03-31         1.81
# 2001-06-30         1.80
# 2001-09-30         1.81
#             euribor3
# Date
# 1994-01-31      6.91
# 1994-02-28      6.86
# 1994-03-31      6.75
# 1994-04-30      6.57
# 1994-05-31      6.24
#             debt_gdp_fr
# Date
# 1999-03-31       60.228
# 1999-06-30       59.523
# 1999-09-30       59.731
# 1999-12-31       59.062
# 2000-03-31       60.377

# %%
#on ajoute également l'indice du VIX:
data_VIX = pd.read_csv('data_regression/VIXCLS.csv', sep=',', parse_dates=['observation_date'], index_col='observation_date')
data_VIX.index = pd.to_datetime(data_VIX.index, format='%Y%m%d')
data_VIX.rename(columns={'VIXCLS': 'VIX'}, inplace=True)

data_VIX["VIX"].fillna(method='ffill', inplace=True)
#data_VIX = data_VIX[data_VIX.index.is_month_start]
data_VIX = data_VIX.resample('MS').mean()
# Out:
# C:\Users\mathi\AppData\Local\Temp\ipykernel_23140\687766187.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_VIX["VIX"].fillna(method='ffill', inplace=True)

# %%
#Aligner les dates de départ:
start_date= pd.to_datetime("2010-01-01")
start_date2= pd.to_datetime("2010-02-01")

end_date= pd.to_datetime("2025-03-01")
end_date2=pd.to_datetime("2024-10-01")





### Tout convertir en base mensuelle + convertir en base 100:
list_BCE_data_copy=[data[data.index>=np.datetime64("2010-01-01")].copy() for data in list_BCE_data]




data_deposit_rate, data_infl_fr, data_infl_for_lt, data_euribor3,data_debt_gdp_fr= list_BCE_data_copy

## Deposit rate: journalier: easy

data_deposit_rate = data_deposit_rate[data_deposit_rate.index.is_month_start]
data_deposit_rate["deposit_rate"]=data_deposit_rate["deposit_rate"]


## inflation fr: mensuel. Caser 1er du mois

new_infl_index= pd.date_range(start=start_date2, end='2025-03-01', freq='MS')

data_infl_fr.index=new_infl_index

data_infl_fr["infl_fr"]=data_infl_fr["infl_fr"]



##infl_lt: Qs. caser 1er du mois

infl_index= data_infl_for_lt.index
new_infl_index = pd.date_range(start=start_date, end='2025-03-01', freq='3MS')
data_infl_for_lt.index= new_infl_index

new_index2= pd.date_range(start=start_date, end='2025-03-01', freq='MS')

data_infl_for_lt = data_infl_for_lt.reindex(new_index2, method='ffill')

data_infl_for_lt["infl_for_lt"]=data_infl_for_lt["infl_for_lt"]

## Euribor: mensuel. Caser 1er du mois suivant


new_infl_index= pd.date_range(start=start_date2, end='2025-03-01', freq='MS')

data_euribor3.index=new_infl_index

data_euribor3["euribor3"]=data_euribor3["euribor3"]

##debt_gdp: Qs. Caser premier du mois suivant.

gdp_index= data_debt_gdp_fr.index
new_gdp_index = pd.date_range(start="2010-04-01", end="2024-10-01", freq='3MS')
data_debt_gdp_fr.index = new_gdp_index

new_index2= pd.date_range(start='2010-04-01', end='2024-12-01', freq='MS')

data_debt_gdp_fr = data_debt_gdp_fr.reindex(new_index2, method='ffill')
print(data_debt_gdp_fr.tail())

##data_VIX : Journaliser, prendre un par mois
data_VIX = data_VIX[data_VIX.index >= start_date].copy()
data_VIX = data_VIX[data_VIX.index <= end_date].copy()
print(data_VIX.head())
print(data_VIX.tail())
# on normalise par leur valeur max pour qu'elles soient entre 0 et 1:
data_VIX["VIX"]=data_VIX["VIX"]/max(data_VIX["VIX"])


list_BCE_data_reindexed=[data_deposit_rate, data_infl_fr, data_infl_for_lt, data_euribor3,data_debt_gdp_fr, data_VIX]


# for data in list_BCE_data_reindexed:
#     print(data.head())
#     data.drop(columns=["Time_period"], inplace=True)

combined_controls= pd.concat(list_BCE_data_reindexed, axis=1)
combined_controls.columns=["deposit_rate", "infl_fr","infl_for_lt","euribor3","debt_gdp_fr", "VIX"]
print(combined_controls.head())
# Out:
#             debt_gdp_fr
# 2024-08-01      112.435
# 2024-09-01      112.435
# 2024-10-01      113.828
# 2024-11-01      113.828
# 2024-12-01      113.828
#                         VIX
# observation_date
# 2010-01-01        20.506500
# 2010-02-01        22.549500
# 2010-03-01        17.767391
# 2010-04-01        17.426364
# 2010-05-01        31.936190
#                         VIX
# observation_date
# 2024-11-01        16.015238
# 2024-12-01        15.793636
# 2025-01-01        16.789130
# 2025-02-01        16.968000
# 2025-03-01        21.841429
#             deposit_rate  infl_fr  infl_for_lt  euribor3  debt_gdp_fr  \
# 2010-01-01         -0.25      NaN         1.91       NaN          NaN
# 2010-02-01         -0.25      1.2         1.91    0.6798          NaN
# 2010-03-01         -0.25      1.4         1.91    0.6617          NaN
# 2010-04-01         -0.25      1.7         1.91    0.6450       85.939
# 2010-05-01         -0.25      1.9         1.91    0.6447       85.939
#
#                  VIX
# 2010-01-01  0.355172
# 2010-02-01  0.390557
# 2010-03-01  0.307731
# 2010-04-01  0.301824
# 2010-05-01  0.553134
# C:\Users\mathi\AppData\Local\Temp\ipykernel_23140\3018582507.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_deposit_rate["deposit_rate"]=data_deposit_rate["deposit_rate"]

# %%
#keep only the lines that are not empty

combined_controls.dropna(inplace=True)
print("Combined controls after dropping NAs:")
print(combined_controls.index)
print(len(combined_controls.index))
# Out:
# Combined controls after dropping NAs:
# DatetimeIndex(['2010-04-01', '2010-05-01', '2010-06-01', '2010-07-01',
#                '2010-08-01', '2010-09-01', '2010-10-01', '2010-11-01',
#                '2010-12-01', '2011-01-01',
#                ...
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01'],
#               dtype='datetime64[ns]', length=177, freq='MS')
# 177

# %% [markdown]
# On étudie d'abord l'autocorrélation:

# %%
#calcul de l'autocorrélation:
autocorrelations = combined_controls.apply(lambda col: col.autocorr() if col.dtype in [np.float64, np.int64] else None)
# Print autocorrelation values
print("Autocorrelation of controls:")
print(autocorrelations)
# Out:
# Autocorrelation of controls:
# deposit_rate    0.909252
# infl_fr         0.982282
# infl_for_lt     0.982401
# euribor3        0.996822
# debt_gdp_fr     0.991287
# VIX             0.744671
# dtype: float64

# %% [markdown]
# On effectue à nouveau un test de stationarité sur les données de contrôle.
#
# On observe qu'ici aussi, on ne peut rejeter l'hypothèse de non stationarité à 5%

# %%
# Test de stationnarité sur les variables de contrôle dans combined_controls:
from statsmodels.tsa.stattools import adfuller

for column in combined_controls.columns:
    print(f"Testing stationarity for {column}:")
    result = adfuller(combined_controls[column])
    print(f"p-value for {column}: {result[1]}")
    print("-" * 50)
# Out:
# Testing stationarity for deposit_rate:
# p-value for deposit_rate: 0.011679061758845994
# --------------------------------------------------
# Testing stationarity for infl_fr:
# p-value for infl_fr: 0.2615184442715165
# --------------------------------------------------
# Testing stationarity for infl_for_lt:
# p-value for infl_for_lt: 0.45776204332373527
# --------------------------------------------------
# Testing stationarity for euribor3:
# p-value for euribor3: 0.09990992765127771
# --------------------------------------------------
# Testing stationarity for debt_gdp_fr:
# p-value for debt_gdp_fr: 0.7302740097314263
# --------------------------------------------------
# Testing stationarity for VIX:
# p-value for VIX: 1.8596681824244545e-05
# --------------------------------------------------

# %% [markdown]
# On décide donc ici aussi de prendre les 1ères différences

# %%
# Différencier toutes les colonnes sauf 'deposit_rate' et 'VIX'
columns_to_diff = combined_controls.columns.difference(['deposit_rate', 'VIX'])
combined_controls_diff = combined_controls[columns_to_diff].diff().dropna()

# Ajouter les colonnes 'deposit_rate' et 'VIX' sans modification
combined_controls_diff['deposit_rate'] = combined_controls['deposit_rate'].loc[combined_controls_diff.index]
combined_controls_diff['VIX'] = combined_controls['VIX'].loc[combined_controls_diff.index]

# Conduct a test of stationarity on each control variable after differencing
for column in combined_controls_diff.columns:
    print(f"Testing stationarity for {column} after differencing:")
    result = adfuller(combined_controls_diff[column])
    print(f"p-value for {column}: {result[1]}")
    print("-" * 50)

# Plot the control variables after differencing
plt.figure(figsize=(12, 8))
for i, column in enumerate(combined_controls_diff.columns, 1):
    plt.subplot(3, 2, i)
    plt.plot(combined_controls_diff[column])
    plt.title(f"Diff {column}")
    plt.xlabel("Date")
    plt.ylabel("Value")
    plt.grid(True)
plt.tight_layout()
plt.show()

print(len(combined_controls_diff.index))
# Out:
# Testing stationarity for debt_gdp_fr after differencing:
# p-value for debt_gdp_fr: 4.850719532621706e-25
# --------------------------------------------------
# Testing stationarity for euribor3 after differencing:
# p-value for euribor3: 0.05677880182393633
# --------------------------------------------------
# Testing stationarity for infl_for_lt after differencing:
# p-value for infl_for_lt: 2.1281794774916287e-06
# --------------------------------------------------
# Testing stationarity for infl_fr after differencing:
# p-value for infl_fr: 0.005702012823132264
# --------------------------------------------------
# Testing stationarity for deposit_rate after differencing:
# p-value for deposit_rate: 0.011623054851135002
# --------------------------------------------------
# Testing stationarity for VIX after differencing:
# p-value for VIX: 1.0910639381293301e-05
# --------------------------------------------------
# 176

# %%
#On vérifie ensuite si les variables macro  sont autocorrélés:
for column in combined_controls_diff.columns:
    autocorr = combined_controls_diff[column].autocorr()
    print(f"{column}: {autocorr}")
# Out:
# debt_gdp_fr: -0.017636849148650283
# euribor3: 0.8669471700567444
# infl_for_lt: -0.0005113781641523895
# infl_fr: 0.10680342126614764
# deposit_rate: 0.9087421065252725
# VIX: 0.7560992290015028

# %%
#on produit enfin une table qui résume les données de combind_controls_diff en indiquant leur autocorrélation et leurs statistique de Dickey Fuller:
from tabulate import tabulate
from statsmodels.tsa.stattools import adfuller
# Compute summary statistics
summary_combined_controls_diff = combined_controls_diff.copy()
summary_stats_controlsdiff = summary_combined_controls_diff.describe().T

# Add autocorrelation column
summary_stats_controlsdiff['autocorrelation'] = summary_combined_controls_diff.apply(
    lambda col: col.autocorr() if col.dtype in [np.float64, np.int64] else None, axis=0
)

# Add Dickey-Fuller test p-value column
summary_stats_controlsdiff['dickey_fuller_pvalue'] = summary_combined_controls_diff.apply(
    lambda col: adfuller(col)[1] if col.dtype in [np.float64, np.int64] else None, axis=0
)

# Format for markdown or text reports
formatted_table_controlsdiff = tabulate(summary_stats_controlsdiff, headers="keys", tablefmt="github")

print(summary_stats_controlsdiff.to_latex(index=True, float_format="%.3f", caption="Summary Statistics with Autocorrelation and Dickey-Fuller Test"))
# Out:
# \begin{table}
# \caption{Summary Statistics with Autocorrelation and Dickey-Fuller Test}
# \begin{tabular}{lrrrrrrrrrr}
# \toprule
#  & count & mean & std & min & 25% & 50% & 75% & max & autocorrelation & dickey_fuller_pvalue \\
# \midrule
# debt_gdp_fr & 176.000 & 0.158 & 1.200 & -3.357 & 0.000 & 0.000 & 0.000 & 11.838 & -0.018 & 0.000 \\
# euribor3 & 176.000 & 0.013 & 0.105 & -0.267 & -0.018 & -0.002 & 0.010 & 0.616 & 0.867 & 0.057 \\
# infl_for_lt & 176.000 & 0.001 & 0.025 & -0.090 & 0.000 & 0.000 & 0.000 & 0.140 & -0.001 & 0.000 \\
# infl_fr & 176.000 & -0.000 & 0.336 & -1.200 & -0.200 & 0.000 & 0.200 & 0.900 & 0.107 & 0.006 \\
# deposit_rate & 176.000 & -0.045 & 0.208 & -0.250 & -0.100 & -0.100 & -0.100 & 0.750 & 0.909 & 0.012 \\
# VIX & 176.000 & 0.317 & 0.112 & 0.175 & 0.242 & 0.290 & 0.360 & 1.000 & 0.756 & 0.000 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ### Régression naïve

# %%
date_range = combined_controls.index
mindate=date_range[0]
maxdate=date_range[-1]
print("Date range:")
print("Min date:", mindate)
print("Max date:", maxdate)
# Out:
# Date range:
# Min date: 2010-04-01 00:00:00
# Max date: 2024-12-01 00:00:00

# %%
#from now on, data used for the regression is copied and has format regdata_

# %%
##factors (dependent)

regdata_factors = data_factors_mensuel.copy()
regdata_factors.dropna(inplace=True)
regdata_factors = regdata_factors[regdata_factors.index >= mindate]
regdata_factors = regdata_factors[regdata_factors.index <= maxdate]
print("Regdata factors after dropping NAs:")
print(regdata_factors.index)

##Nick bloom (independent)
regdata_NB = data_NB.copy()
regdata_NB.dropna(inplace=True)
regdata_NB = regdata_NB[regdata_NB.index >= mindate]
regdata_NB = regdata_NB[regdata_NB.index <= maxdate]
print("Regdata NB after dropping NAs:")
print(regdata_NB.index)
# Out:
# Regdata factors after dropping NAs:
# DatetimeIndex(['2010-04-01', '2010-05-01', '2010-06-01', '2010-07-01',
#                '2010-08-01', '2010-09-01', '2010-10-01', '2010-11-01',
#                '2010-12-01', '2011-01-01',
#                ...
#                '2023-12-01', '2024-01-01', '2024-02-01', '2024-03-01',
#                '2024-04-01', '2024-05-01', '2024-06-01', '2024-07-01',
#                '2024-08-01', '2024-09-01'],
#               dtype='datetime64[ns]', name='Date', length=174, freq='MS')
# Regdata NB after dropping NAs:
# DatetimeIndex(['2010-04-01', '2010-05-01', '2010-06-01', '2010-07-01',
#                '2010-08-01', '2010-09-01', '2010-10-01', '2010-11-01',
#                '2010-12-01', '2011-01-01',
#                ...
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01'],
#               dtype='datetime64[ns]', name='Date', length=177, freq=None)

# %%
## generate single dataframe for the regression

regdata_all= pd.concat([regdata_factors, regdata_NB, combined_controls.copy()], axis=1)
print(regdata_all.tail())
# Out:
#             factor 1  factor 2  factor 3  factor 4  factor 5  factor 6  \
# 2024-08-01  4.526080  2.579160  0.722397  2.584113  3.076281  0.020249
# 2024-09-01  4.477882  2.427793  0.514966  2.542936  3.036207 -0.073319
# 2024-10-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2024-11-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2024-12-01       NaN       NaN       NaN       NaN       NaN       NaN
#
#             factor 7  factor 8  factor 9  factor 10  ... Italy_News_Index  \
# 2024-08-01  3.665668  3.845875 -2.526751   6.997456  ...        70.598771
# 2024-09-01  3.758639  3.800594 -2.682128   7.188458  ...       110.579817
# 2024-10-01       NaN       NaN       NaN        NaN  ...       100.498001
# 2024-11-01       NaN       NaN       NaN        NaN  ...       124.806529
# 2024-12-01       NaN       NaN       NaN        NaN  ...       133.739942
#
#             UK_News_Index  France_News_Index  Spain_News_Index  deposit_rate  \
# 2024-08-01     181.544052           0.645256         72.254676         -0.25
# 2024-09-01     303.677826           0.759451         77.024802         -0.25
# 2024-10-01     388.310662           0.560861        143.935673         -0.25
# 2024-11-01     396.505948           0.847226        124.524185         -0.25
# 2024-12-01     409.251621           0.987950        208.087094         -0.25
#
#             infl_fr  infl_for_lt  euribor3  debt_gdp_fr       VIX
# 2024-08-01      2.7         2.02    3.6848      112.435  0.334488
# 2024-09-01      2.2         2.02    3.5476      112.435  0.305928
# 2024-10-01      1.4         2.01    3.4337      113.828  0.345722
# 2024-11-01      1.6         2.01    3.1666      113.828  0.277383
# 2024-12-01      1.7         2.01    3.0068      113.828  0.273545
#
# [5 rows x 24 columns]

# %%
## Conduct most basic linear regression on whole period 
#then include time and fixed effects

# Create lagged term of Y1
regdata_all['factor1_lagged'] = regdata_all[[f"factor {i+1}" for i in range(10)]].shift(1).to_numpy(dtype=float)[:, 0]
regdata_all.dropna(inplace=True)
print("Regdata all after dropping NAs:")

print(regdata_all.tail())
# Out:
# Regdata all after dropping NAs:
#             factor 1  factor 2  factor 3  factor 4  factor 5  factor 6  \
# 2024-05-01  4.685066  3.284303  1.646417  2.631871  3.134776  0.187240
# 2024-06-01  4.594397  3.223359  1.729716  2.746980  3.089536  0.314030
# 2024-07-01  4.614542  3.050871  1.349081  2.652789  3.149746  0.272270
# 2024-08-01  4.526080  2.579160  0.722397  2.584113  3.076281  0.020249
# 2024-09-01  4.477882  2.427793  0.514966  2.542936  3.036207 -0.073319
#
#             factor 7  factor 8  factor 9  factor 10  ... UK_News_Index  \
# 2024-05-01  3.355463  4.151631 -2.103642   6.093354  ...    265.262359
# 2024-06-01  3.459300  3.821745 -2.177031   6.571534  ...    218.630897
# 2024-07-01  3.602697  3.924727 -2.346739   6.709139  ...    113.290842
# 2024-08-01  3.665668  3.845875 -2.526751   6.997456  ...    181.544052
# 2024-09-01  3.758639  3.800594 -2.682128   7.188458  ...    303.677826
#
#             France_News_Index  Spain_News_Index  deposit_rate  infl_fr  \
# 2024-05-01           0.529810         66.321607          0.25      2.4
# 2024-06-01           0.712232        148.018104          0.25      2.6
# 2024-07-01           0.946574         81.712295         -0.25      2.5
# 2024-08-01           0.645256         72.254676         -0.25      2.7
# 2024-09-01           0.759451         77.024802         -0.25      2.2
#
#             infl_for_lt  euribor3  debt_gdp_fr       VIX  factor1_lagged
# 2024-05-01         2.04    3.8864      110.786  0.226176        4.952051
# 2024-06-01         2.04    3.8137      110.786  0.219392        4.685066
# 2024-07-01         2.02    3.7245      112.435  0.248956        4.594397
# 2024-08-01         2.02    3.6848      112.435  0.334488        4.614542
# 2024-09-01         2.02    3.5476      112.435  0.305928        4.526080
#
# [5 rows x 25 columns]

# %%
### FOnction de régression simple:

import statsmodels.api as sm




def simple_regression(data, factor: int,  controls, lagged=True):

    dependent = f"factor {factor+1}"
    independent = ["France_News_Index"]

    
    independent += controls

    

    # Define X1 and Y1 with the lagged term included
    X = data[independent].to_numpy(dtype=float)

    Y = data[dependent].to_numpy(dtype=float)

    # Fit the model using statsmodels to get t-values
    X = sm.add_constant(X)  # Adds a constant term to the predictor
    model = sm.OLS(Y, X).fit()
    explanatory_vars = ['const'] + independent  # Include constant and explanatory variable names
    model_summary = model.summary(xname=explanatory_vars)  # Use xname to set variable names
    print(f"#######################  Regression for factor {factor+1}: #######################")
    print(model_summary)


restricted_controls=["infl_fr","infl_for_lt","debt_gdp_fr"]
full_controls=["deposit_rate", "infl_fr","infl_for_lt","euribor3","debt_gdp_fr"]

for i in range(10):
    simple_regression(regdata_all,i, restricted_controls, lagged=False)
# Out:
# #######################  Regression for factor 1: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.557
# Model:                            OLS   Adj. R-squared:                  0.547
# Method:                 Least Squares   F-statistic:                     52.91
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           8.70e-29
# Time:                        16:15:09   Log-Likelihood:                -250.50
# No. Observations:                 173   AIC:                             511.0
# Df Residuals:                     168   BIC:                             526.8
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               -25.6125      2.670     -9.591      0.000     -30.884     -20.340
# France_News_Index    -0.7041      0.575     -1.225      0.222      -1.839       0.430
# infl_fr              -0.2587      0.091     -2.853      0.005      -0.438      -0.080
# infl_for_lt          10.0082      1.092      9.161      0.000       7.852      12.165
# debt_gdp_fr           0.0782      0.011      6.872      0.000       0.056       0.101
# ==============================================================================
# Omnibus:                        8.308   Durbin-Watson:                   0.108
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):                9.536
# Skew:                           0.369   Prob(JB):                      0.00850
# Kurtosis:                       3.882   Cond. No.                     3.65e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.65e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #######################  Regression for factor 2: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.571
# Model:                            OLS   Adj. R-squared:                  0.561
# Method:                 Least Squares   F-statistic:                     56.00
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           6.00e-30
# Time:                        16:15:09   Log-Likelihood:                -227.18
# No. Observations:                 173   AIC:                             464.4
# Df Residuals:                     168   BIC:                             480.1
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               -13.0082      2.334     -5.574      0.000     -17.616      -8.401
# France_News_Index    -0.8192      0.502     -1.631      0.105      -1.811       0.172
# infl_fr               0.1065      0.079      1.344      0.181      -0.050       0.263
# infl_for_lt           6.4624      0.955      6.769      0.000       4.578       8.347
# debt_gdp_fr           0.0129      0.010      1.302      0.195      -0.007       0.033
# ==============================================================================
# Omnibus:                        1.244   Durbin-Watson:                   0.097
# Prob(Omnibus):                  0.537   Jarque-Bera (JB):                1.324
# Skew:                          -0.193   Prob(JB):                        0.516
# Kurtosis:                       2.814   Cond. No.                     3.65e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.65e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #######################  Regression for factor 3: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.580
# Model:                            OLS   Adj. R-squared:                  0.570
# Method:                 Least Squares   F-statistic:                     58.03
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           1.10e-30
# Time:                        16:15:09   Log-Likelihood:                -190.00
# No. Observations:                 173   AIC:                             390.0
# Df Residuals:                     168   BIC:                             405.8
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -4.3285      1.882     -2.299      0.023      -8.045      -0.612
# France_News_Index    -0.3622      0.405     -0.894      0.373      -1.162       0.438
# infl_fr               0.2204      0.064      3.448      0.001       0.094       0.347
# infl_for_lt           3.8871      0.770      5.048      0.000       2.367       5.407
# debt_gdp_fr          -0.0335      0.008     -4.174      0.000      -0.049      -0.018
# ==============================================================================
# Omnibus:                        2.766   Durbin-Watson:                   0.186
# Prob(Omnibus):                  0.251   Jarque-Bera (JB):                2.246
# Skew:                           0.150   Prob(JB):                        0.325
# Kurtosis:                       2.530   Cond. No.                     3.65e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.65e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #######################  Regression for factor 4: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.652
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     78.84
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           1.56e-37
# Time:                        16:15:09   Log-Likelihood:                -167.62
# No. Observations:                 173   AIC:                             345.2
# Df Residuals:                     168   BIC:                             361.0
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               -15.9323      1.654     -9.633      0.000     -19.198     -12.667
# France_News_Index    -0.0882      0.356     -0.248      0.805      -0.791       0.614
# infl_fr              -0.1568      0.056     -2.792      0.006      -0.268      -0.046
# infl_for_lt           7.9885      0.677     11.807      0.000       6.653       9.324
# debt_gdp_fr           0.0152      0.007      2.155      0.033       0.001       0.029
# ==============================================================================
# Omnibus:                        3.001   Durbin-Watson:                   0.248
# Prob(Omnibus):                  0.223   Jarque-Bera (JB):                2.756
# Skew:                          -0.308   Prob(JB):                        0.252
# Kurtosis:                       3.053   Cond. No.                     3.65e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.65e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #######################  Regression for factor 5: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.634
# Model:                            OLS   Adj. R-squared:                  0.625
# Method:                 Least Squares   F-statistic:                     72.82
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           1.11e-35
# Time:                        16:15:09   Log-Likelihood:                -248.11
# No. Observations:                 173   AIC:                             506.2
# Df Residuals:                     168   BIC:                             522.0
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -3.0606      2.634     -1.162      0.247      -8.260       2.139
# France_News_Index    -0.4407      0.567     -0.778      0.438      -1.560       0.678
# infl_fr               0.2851      0.089      3.187      0.002       0.108       0.462
# infl_for_lt           6.2973      1.077      5.845      0.000       4.170       8.424
# debt_gdp_fr          -0.0770      0.011     -6.866      0.000      -0.099      -0.055
# ==============================================================================
# Omnibus:                       23.189   Durbin-Watson:                   0.121
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                6.756
# Skew:                          -0.086   Prob(JB):                       0.0341
# Kurtosis:                       2.047   Cond. No.                     3.65e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.65e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #######################  Regression for factor 6: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.436
# Method:                 Least Squares   F-statistic:                     34.29
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           6.51e-21
# Time:                        16:15:09   Log-Likelihood:                -316.82
# No. Observations:                 173   AIC:                             643.6
# Df Residuals:                     168   BIC:                             659.4
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.3971      3.918      1.122      0.263      -3.338      12.132
# France_News_Index     0.0902      0.843      0.107      0.915      -1.574       1.755
# infl_fr               0.1420      0.133      1.067      0.287      -0.121       0.405
# infl_for_lt           4.6495      1.603      2.901      0.004       1.485       7.814
# debt_gdp_fr          -0.1363      0.017     -8.167      0.000      -0.169      -0.103
# ==============================================================================
# Omnibus:                        7.075   Durbin-Watson:                   0.066
# Prob(Omnibus):                  0.029   Jarque-Bera (JB):                4.379
# Skew:                           0.216   Prob(JB):                        0.112
# Kurtosis:                       2.351   Cond. No.                     3.65e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.65e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #######################  Regression for factor 7: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.477
# Model:                            OLS   Adj. R-squared:                  0.465
# Method:                 Least Squares   F-statistic:                     38.31
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           9.28e-23
# Time:                        16:15:09   Log-Likelihood:                -302.52
# No. Observations:                 173   AIC:                             615.0
# Df Residuals:                     168   BIC:                             630.8
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -4.3711      3.607     -1.212      0.227     -11.493       2.751
# France_News_Index    -1.2052      0.776     -1.552      0.122      -2.738       0.327
# infl_fr              -0.6076      0.123     -4.960      0.000      -0.849      -0.366
# infl_for_lt           9.5085      1.476      6.443      0.000       6.595      12.422
# debt_gdp_fr          -0.0753      0.015     -4.898      0.000      -0.106      -0.045
# ==============================================================================
# Omnibus:                       10.853   Durbin-Watson:                   0.127
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):                5.064
# Skew:                           0.169   Prob(JB):                       0.0795
# Kurtosis:                       2.233   Cond. No.                     3.65e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.65e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #######################  Regression for factor 8: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.360
# Model:                            OLS   Adj. R-squared:                  0.345
# Method:                 Least Squares   F-statistic:                     23.63
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           1.62e-15
# Time:                        16:15:09   Log-Likelihood:                -328.96
# No. Observations:                 173   AIC:                             667.9
# Df Residuals:                     168   BIC:                             683.7
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               -14.3569      4.203     -3.416      0.001     -22.655      -6.059
# France_News_Index     0.4077      0.905      0.451      0.653      -1.378       2.193
# infl_fr               0.0837      0.143      0.586      0.559      -0.198       0.365
# infl_for_lt           8.0234      1.719      4.666      0.000       4.629      11.418
# debt_gdp_fr           0.0052      0.018      0.290      0.772      -0.030       0.041
# ==============================================================================
# Omnibus:                       16.959   Durbin-Watson:                   0.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.517
# Skew:                          -0.350   Prob(JB):                       0.0141
# Kurtosis:                       2.169   Cond. No.                     3.65e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.65e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #######################  Regression for factor 9: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.391
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     26.98
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           2.70e-17
# Time:                        16:15:09   Log-Likelihood:                -377.34
# No. Observations:                 173   AIC:                             764.7
# Df Residuals:                     168   BIC:                             780.4
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                22.5299      5.559      4.053      0.000      11.555      33.505
# France_News_Index    -2.4350      1.196     -2.035      0.043      -4.797      -0.073
# infl_fr              -0.0584      0.189     -0.310      0.757      -0.431       0.314
# infl_for_lt          -2.7991      2.274     -1.231      0.220      -7.288       1.690
# debt_gdp_fr          -0.1637      0.024     -6.912      0.000      -0.210      -0.117
# ==============================================================================
# Omnibus:                        0.079   Durbin-Watson:                   0.064
# Prob(Omnibus):                  0.961   Jarque-Bera (JB):                0.193
# Skew:                           0.039   Prob(JB):                        0.908
# Kurtosis:                       2.856   Cond. No.                     3.65e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.65e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #######################  Regression for factor 10: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.552
# Model:                            OLS   Adj. R-squared:                  0.541
# Method:                 Least Squares   F-statistic:                     51.65
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           2.63e-28
# Time:                        16:15:09   Log-Likelihood:                -344.67
# No. Observations:                 173   AIC:                             699.3
# Df Residuals:                     168   BIC:                             715.1
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 6.8316      4.603      1.484      0.140      -2.255      15.918
# France_News_Index     1.2460      0.991      1.258      0.210      -0.709       3.201
# infl_fr              -0.3362      0.156     -2.151      0.033      -0.645      -0.028
# infl_for_lt          -8.2944      1.883     -4.405      0.000     -12.011      -4.577
# debt_gdp_fr           0.1576      0.020      8.039      0.000       0.119       0.196
# ==============================================================================
# Omnibus:                        3.545   Durbin-Watson:                   0.069
# Prob(Omnibus):                  0.170   Jarque-Bera (JB):                3.606
# Skew:                          -0.333   Prob(JB):                        0.165
# Kurtosis:                       2.761   Cond. No.                     3.65e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.65e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
def plot_all_variables(data, features_to_plot):
    """
    Plots all the variables in the provided DataFrame.

    Parameters:
    - data: DataFrame containing the data to plot.
    - features_to_plot: List of column names to plot.
    """
    for feature in features_to_plot:
        if feature in data.columns:
            plt.figure(figsize=(10, 5))
            plt.plot(data.index, data[feature], label=feature)
            plt.title(f"Time Series of {feature}")
            plt.xlabel("Date")
            plt.ylabel(feature)
            plt.legend()
            plt.grid()
            plt.show()

list_features_to_plot=[f"factor {i+1}" for i in range(10)] + ["Deposit-rate", "France_News_Index", " infl_fr", "infl_for_lt", "euribor3", "debt_gdp_fr"]
# Plot all variables in the DataFrame
#plot_all_variables(regdata_all, list_features_to_plot)

# %% [markdown]
# ### Régressions sur diff premières

# %% [markdown]
# Ici, on effectue des régressions en utilisant les données différenciées, ce qui doit permettre d'obtenir des coefs non biaisés

# %%
#on commence par récupérer les dates de la régression:
date_range_diff = combined_controls_diff.index
date_range_diff_factors = data_factors_diff.index
mindate_diff = max(date_range_diff[0], date_range_diff_factors[0])
maxdate_diff = min(date_range_diff[-1], date_range_diff_factors[-1])
print("Date range:")
print("Min date:", mindate_diff)
print("Max date:", maxdate_diff)
# Out:
# Date range:
# Min date: 2010-05-01 00:00:00
# Max date: 2024-09-01 00:00:00

# %%
#on choisit ensuite les variables à utiliser pour la régression:

##factors (dependent)

regdata_factors_diff = data_factors_diff.copy()
regdata_factors_diff.dropna(inplace=True)
regdata_factors_diff = regdata_factors_diff[regdata_factors_diff.index >= mindate_diff]
regdata_factors_diff = regdata_factors_diff[regdata_factors_diff.index <= maxdate_diff]
print("Regdata factors after dropping NAs:")
print(regdata_factors_diff.index)

##Nick bloom (independent). Ici, on a pas différencié car les données sotn stationnaires. on peut garder la série brute.
#on renomme nos données "diff" pour éviter les confusions avec le cas précédént, car les dates retenues diffèrent
regdata_NB_diff = data_NB.copy()
regdata_NB_diff.dropna(inplace=True)
regdata_NB_diff = regdata_NB_diff[regdata_NB_diff.index >= mindate_diff]
regdata_NB_diff = regdata_NB_diff[regdata_NB_diff.index <= maxdate_diff]
print("Regdata NB after dropping NAs:")
print(regdata_NB_diff.index)
# Out:
# Regdata factors after dropping NAs:
# DatetimeIndex(['2010-05-01', '2010-06-01', '2010-07-01', '2010-08-01',
#                '2010-09-01', '2010-10-01', '2010-11-01', '2010-12-01',
#                '2011-01-01', '2011-02-01',
#                ...
#                '2023-12-01', '2024-01-01', '2024-02-01', '2024-03-01',
#                '2024-04-01', '2024-05-01', '2024-06-01', '2024-07-01',
#                '2024-08-01', '2024-09-01'],
#               dtype='datetime64[ns]', name='Date', length=173, freq='MS')
# Regdata NB after dropping NAs:
# DatetimeIndex(['2010-05-01', '2010-06-01', '2010-07-01', '2010-08-01',
#                '2010-09-01', '2010-10-01', '2010-11-01', '2010-12-01',
#                '2011-01-01', '2011-02-01',
#                ...
#                '2023-12-01', '2024-01-01', '2024-02-01', '2024-03-01',
#                '2024-04-01', '2024-05-01', '2024-06-01', '2024-07-01',
#                '2024-08-01', '2024-09-01'],
#               dtype='datetime64[ns]', name='Date', length=173, freq=None)

# %%
## Comme précédemment, on concatène nos données prêtes pour la régression
## On remarque ici des grandes différences de niveau entre la mesure de l'incertitude de Nick Bloom et les variables différenciées, ce qui rend l'interprétation plus difficile.
regdata_all_diff= pd.concat([regdata_factors_diff, regdata_NB_diff, combined_controls_diff.copy()], axis=1)
regdata_all_diff.dropna(inplace=True)
regdata_all_diff.drop(["Year", "Month"], axis=1, inplace=True)

print(regdata_all_diff.columns)
# Out:
# Index(['factor 1', 'factor 2', 'factor 3', 'factor 4', 'factor 5', 'factor 6',
#        'factor 7', 'factor 8', 'factor 9', 'factor 10', 'European_News_Index',
#        'Germany_News_Index', 'Italy_News_Index', 'UK_News_Index',
#        'France_News_Index', 'Spain_News_Index', 'debt_gdp_fr', 'euribor3',
#        'infl_for_lt', 'infl_fr', 'deposit_rate', 'VIX'],
#       dtype='object')

# %% [markdown]
# Maintenant que nos données sont prêtes, on les visualise une dernière fois avant de régresser

# %%
regdata_all_diff
# Out:
#             factor 1  factor 2  factor 3  factor 4  factor 5  factor 6  \
# 2010-05-01 -0.040153 -0.130892 -0.407594 -0.554353 -0.181896 -0.283831
# 2010-06-01 -0.078729  0.086223  0.270745 -0.051001 -0.092604  0.184688
# 2010-07-01  0.153674  0.229756  0.260015  0.042473 -0.482184 -0.349471
# 2010-08-01 -0.014158  0.045832 -0.098947 -0.398820 -0.218371 -0.181066
# 2010-09-01 -0.217198  0.086511  0.381443 -0.125384 -0.097760  0.123255
# ...              ...       ...       ...       ...       ...       ...
# 2024-05-01 -0.266985  0.015691  0.408072  0.092153 -0.143897 -0.022878
# 2024-06-01 -0.090669 -0.060944  0.083300  0.115109 -0.045240  0.126790
# 2024-07-01  0.020145 -0.172488 -0.380635 -0.094191  0.060210 -0.041759
# 2024-08-01 -0.088462 -0.471712 -0.626684 -0.068676 -0.073465 -0.252021
# 2024-09-01 -0.048198 -0.151366 -0.207432 -0.041177 -0.040074 -0.093568
#
#             factor 7  factor 8  factor 9  factor 10  ...  Italy_News_Index  \
# 2010-05-01  0.130121  0.199721 -0.007121   0.392414  ...        114.949492
# 2010-06-01 -0.197352 -0.307266  0.534439  -0.075577  ...        160.790398
# 2010-07-01  0.280146 -0.460832 -0.160729   0.041843  ...        144.467760
# 2010-08-01 -0.293417 -0.312757  0.573774   0.135859  ...        111.565914
# 2010-09-01 -0.162134 -0.254228  0.242582  -0.040299  ...        126.127850
# ...              ...       ...       ...        ...  ...               ...
# 2024-05-01  0.058190 -0.112007 -0.154522   0.252208  ...         82.447442
# 2024-06-01  0.103836 -0.329886 -0.073389   0.478179  ...        106.162974
# 2024-07-01  0.143397  0.102983 -0.169708   0.137606  ...         98.660453
# 2024-08-01  0.062972 -0.078853 -0.180012   0.288317  ...         70.598771
# 2024-09-01  0.092970 -0.045281 -0.155377   0.191003  ...        110.579817
#
#             UK_News_Index  France_News_Index  Spain_News_Index  debt_gdp_fr  \
# 2010-05-01     238.265501           0.640806        162.265207        0.000
# 2010-06-01     242.656893           0.235731        130.798785        0.000
# 2010-07-01     237.969429           0.325628        130.476739        2.211
# 2010-08-01     269.244242           0.297195        158.805039        0.000
# 2010-09-01     233.244366           0.373328        114.105442        0.000
# ...                   ...                ...               ...          ...
# 2024-05-01     265.262359           0.529810         66.321607        0.000
# 2024-06-01     218.630897           0.712232        148.018104        0.000
# 2024-07-01     113.290842           0.946574         81.712295        1.649
# 2024-08-01     181.544052           0.645256         72.254676        0.000
# 2024-09-01     303.677826           0.759451         77.024802        0.000
#
#             euribor3  infl_for_lt  infl_fr  deposit_rate       VIX
# 2010-05-01   -0.0003         0.00      0.2         -0.25  0.553134
# 2010-06-01    0.0418         0.00      0.0         -0.25  0.518151
# 2010-07-01    0.0411         0.04     -0.2         -0.25  0.446375
# 2010-08-01    0.1212         0.00      0.2         -0.25  0.428598
# 2010-09-01    0.0467         0.00     -0.3         -0.25  0.389054
# ...              ...          ...      ...           ...       ...
# 2024-05-01   -0.0360         0.00      0.0          0.25  0.226176
# 2024-06-01   -0.0727         0.00      0.2          0.25  0.219392
# 2024-07-01   -0.0892        -0.02     -0.1         -0.25  0.248956
# 2024-08-01   -0.0397         0.00      0.2         -0.25  0.334488
# 2024-09-01   -0.1372         0.00     -0.5         -0.25  0.305928
#
# [173 rows x 22 columns]

# %%
# Plot the data used for the regression
num_columns = len(regdata_all_diff.columns)
num_rows = (num_columns + 1) // 2  # Calculate the number of rows needed for 2 columns per row

plt.figure(figsize=(12, 4 * num_rows))  # Adjust figure height based on the number of rows
for i, column in enumerate(regdata_all_diff.columns, 1):
    plt.subplot(num_rows, 2, i)
    plt.plot(regdata_all_diff[column])
    plt.title(str(column))
    plt.xlabel("Date")
    plt.ylabel("Value")
    plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# On étudie enfin les corrélations entre les variables de régression:
# - d'abord les facteurs
# - ensuite les contrôles pour identifier les contrôles redondants
# - enfin le total

# %%
#on s'intéresse  aux correlations entre les contrôles pour limiter la multicolinéarité:

import seaborn as sns
# Calculate the cross-correlation matrix
correlation_matrix_regdiff = regdata_all_diff.copy()[["deposit_rate", "infl_fr","infl_for_lt","euribor3","debt_gdp_fr", "VIX"]].corr()

# Plot the cross-correlation matrix of factors
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_regdiff, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Matrice de corrélation des contrôles différenciés")
plt.show()

# %%
import seaborn as sns
# Calculate the cross-correlation matrix
correlation_matrix_regdiff = regdata_all_diff.copy()[[f"factor {i}" for i in range(1,11)]].corr()

# Plot the cross-correlation matrix of factors
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_regdiff, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Matrice de corrélations des facteurs différenciés")
plt.show()

# %%
#on s'intéresse  aux correlations entre les contrôles pour limiter la multicolinéarité:

import seaborn as sns
# Calculate the cross-correlation matrix
corr_allvar = regdata_all_diff.copy().drop(["European_News_Index", "Germany_News_Index", "Italy_News_Index","UK_News_Index","Spain_News_Index"], axis=1)
correlation_matrix_regdiff = corr_allvar.corr()

# Plot the cross-correlation matrix of factors
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_regdiff, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Matrice de corrélation des contrôles différenciés")
plt.show()

# %%
## COmparaison VIX et News Index:

# %% [markdown]
# On code enfin les différentes régressions:
# - d'abord une régression linéaire simple
# - ensuite une régression linéaire prenant en compte l'autocorrélation des erreurs

# %%
### FOnction de régression simple:

import statsmodels.api as sm

def regression_diff(data, factor: int, independent, controls,robust=False):

    dependent = f"factor {factor+1}"

    indep = independent.copy()
    indep += controls.copy()
    X = data[indep].to_numpy(dtype=float)


    Y = data[dependent].to_numpy(dtype=float)


    # Fit the model using statsmodels to get t-values
    X = sm.add_constant(X)  # Adds a constant term to the predictor


    if robust:
        # Fit the model using HAC (Heteroskedasticity and Autocorrelation Consistent) standard errors
        model = sm.OLS(Y, X).fit(cov_type='HAC', cov_kwds={'maxlags': 1})
    else:
        model = sm.OLS(Y, X).fit()
    explanatory_vars = ['const'] + indep  # Include constant and explanatory variable names
    model_summary = model.summary(xname=explanatory_vars)  # Use xname to set variable names
    print(f"#######################  Regression for factor {factor+1}: #######################")
    print(model_summary)

    if robust:
        print("Robust standard errors used.")
    else:
        print("Standard errors used.")

    
independent = ["France_News_Index"]
restricted_controls=["infl_fr","infl_for_lt","debt_gdp_fr", "VIX"]
full_controls=["deposit_rate", "infl_fr","infl_for_lt","euribor3","debt_gdp_fr", "VIX"]

for i in range(10):
    regression_diff(regdata_all_diff,i, independent, restricted_controls,robust=True,)
# Out:
# #######################  Regression for factor 1: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     1.999
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):             0.0813
# Time:                        16:15:16   Log-Likelihood:                 61.330
# No. Observations:                 173   AIC:                            -110.7
# Df Residuals:                     167   BIC:                            -91.74
# Df Model:                           5
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.0682      0.064     -1.062      0.288      -0.194       0.058
# France_News_Index     0.2766      0.098      2.813      0.005       0.084       0.469
# infl_fr              -0.0493      0.047     -1.048      0.295      -0.142       0.043
# infl_for_lt           0.4177      0.465      0.899      0.369      -0.493       1.328
# debt_gdp_fr         6.23e-05      0.007      0.009      0.993      -0.013       0.013
# VIX                  -0.1227      0.206     -0.595      0.552      -0.527       0.281
# ==============================================================================
# Omnibus:                       17.613   Durbin-Watson:                   0.951
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.780
# Skew:                           0.263   Prob(JB):                     2.10e-12
# Kurtosis:                       5.680   Cond. No.                         50.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 2: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                     1.506
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):              0.190
# Time:                        16:15:16   Log-Likelihood:                 52.080
# No. Observations:                 173   AIC:                            -92.16
# Df Residuals:                     167   BIC:                            -73.24
# Df Model:                           5
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.0453      0.059     -0.771      0.441      -0.160       0.070
# France_News_Index    -0.0489      0.085     -0.577      0.564      -0.215       0.117
# infl_fr               0.0136      0.044      0.305      0.760      -0.074       0.101
# infl_for_lt           0.0990      0.358      0.277      0.782      -0.602       0.800
# debt_gdp_fr          -0.0125      0.006     -2.047      0.041      -0.024      -0.001
# VIX                   0.2517      0.197      1.278      0.201      -0.134       0.638
# ==============================================================================
# Omnibus:                       54.969   Durbin-Watson:                   1.237
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1279.109
# Skew:                           0.422   Prob(JB):                    1.76e-278
# Kurtosis:                      16.294   Cond. No.                         50.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 3: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     1.805
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):              0.115
# Time:                        16:15:16   Log-Likelihood:                -21.753
# No. Observations:                 173   AIC:                             55.51
# Df Residuals:                     167   BIC:                             74.43
# Df Model:                           5
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.0067      0.088     -0.076      0.939      -0.180       0.166
# France_News_Index    -0.3365      0.148     -2.277      0.023      -0.626      -0.047
# infl_fr               0.0828      0.086      0.958      0.338      -0.087       0.252
# infl_for_lt          -0.6933      0.921     -0.753      0.452      -2.499       1.112
# debt_gdp_fr          -0.0151      0.011     -1.314      0.189      -0.038       0.007
# VIX                   0.5305      0.253      2.098      0.036       0.035       1.026
# ==============================================================================
# Omnibus:                       16.799   Durbin-Watson:                   1.651
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.107
# Skew:                          -0.096   Prob(JB):                     1.46e-13
# Kurtosis:                       5.857   Cond. No.                         50.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 4: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.098
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):              0.363
# Time:                        16:15:16   Log-Likelihood:                 4.6080
# No. Observations:                 173   AIC:                             2.784
# Df Residuals:                     167   BIC:                             21.70
# Df Model:                           5
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.0696      0.076     -0.921      0.357      -0.218       0.079
# France_News_Index     0.2307      0.121      1.902      0.057      -0.007       0.468
# infl_fr               0.0734      0.065      1.125      0.261      -0.054       0.201
# infl_for_lt          -0.2264      1.020     -0.222      0.824      -2.226       1.773
# debt_gdp_fr           0.0074      0.013      0.580      0.562      -0.018       0.032
# VIX                  -0.1089      0.201     -0.542      0.588      -0.503       0.285
# ==============================================================================
# Omnibus:                        4.979   Durbin-Watson:                   1.466
# Prob(Omnibus):                  0.083   Jarque-Bera (JB):                6.975
# Skew:                           0.045   Prob(JB):                       0.0306
# Kurtosis:                       3.980   Cond. No.                         50.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 5: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     2.478
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):             0.0340
# Time:                        16:15:16   Log-Likelihood:                -31.636
# No. Observations:                 173   AIC:                             75.27
# Df Residuals:                     167   BIC:                             94.19
# Df Model:                           5
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.0829      0.090     -0.921      0.357      -0.260       0.094
# France_News_Index     0.0850      0.142      0.599      0.549      -0.193       0.363
# infl_fr               0.1451      0.053      2.729      0.006       0.041       0.249
# infl_for_lt           0.3683      0.715      0.515      0.607      -1.033       1.770
# debt_gdp_fr          -0.0141      0.011     -1.262      0.207      -0.036       0.008
# VIX                   0.1115      0.221      0.505      0.614      -0.321       0.544
# ==============================================================================
# Omnibus:                       17.453   Durbin-Watson:                   1.757
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               58.312
# Skew:                          -0.195   Prob(JB):                     2.18e-13
# Kurtosis:                       5.817   Cond. No.                         50.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 6: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     2.086
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):             0.0695
# Time:                        16:15:16   Log-Likelihood:                -45.842
# No. Observations:                 173   AIC:                             103.7
# Df Residuals:                     167   BIC:                             122.6
# Df Model:                           5
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.2892      0.100     -2.906      0.004      -0.484      -0.094
# France_News_Index     0.2873      0.181      1.591      0.112      -0.067       0.641
# infl_fr               0.1052      0.062      1.697      0.090      -0.016       0.227
# infl_for_lt          -0.6776      0.668     -1.015      0.310      -1.987       0.631
# debt_gdp_fr          -0.0025      0.014     -0.179      0.858      -0.029       0.024
# VIX                   0.4151      0.230      1.809      0.070      -0.035       0.865
# ==============================================================================
# Omnibus:                        0.019   Durbin-Watson:                   1.170
# Prob(Omnibus):                  0.990   Jarque-Bera (JB):                0.103
# Skew:                          -0.021   Prob(JB):                        0.950
# Kurtosis:                       2.888   Cond. No.                         50.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 7: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     1.127
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):              0.348
# Time:                        16:15:16   Log-Likelihood:                -53.807
# No. Observations:                 173   AIC:                             119.6
# Df Residuals:                     167   BIC:                             138.5
# Df Model:                           5
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.1065      0.102     -1.040      0.298      -0.307       0.094
# France_News_Index     0.4408      0.221      1.990      0.047       0.007       0.875
# infl_fr               0.0779      0.080      0.973      0.331      -0.079       0.235
# infl_for_lt           0.6902      0.945      0.731      0.465      -1.161       2.542
# debt_gdp_fr           0.0066      0.014      0.477      0.633      -0.021       0.034
# VIX                  -0.3563      0.238     -1.498      0.134      -0.823       0.110
# ==============================================================================
# Omnibus:                        5.121   Durbin-Watson:                   1.257
# Prob(Omnibus):                  0.077   Jarque-Bera (JB):                5.142
# Skew:                          -0.280   Prob(JB):                       0.0765
# Kurtosis:                       3.633   Cond. No.                         50.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 8: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                    0.8371
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):              0.525
# Time:                        16:15:16   Log-Likelihood:                -81.291
# No. Observations:                 173   AIC:                             174.6
# Df Residuals:                     167   BIC:                             193.5
# Df Model:                           5
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.1401      0.142     -0.985      0.325      -0.419       0.139
# France_News_Index    -0.0658      0.259     -0.254      0.800      -0.574       0.443
# infl_fr               0.0952      0.075      1.273      0.203      -0.051       0.242
# infl_for_lt           0.3170      1.121      0.283      0.777      -1.880       2.514
# debt_gdp_fr          -0.0171      0.015     -1.119      0.263      -0.047       0.013
# VIX                   0.5705      0.333      1.715      0.086      -0.081       1.222
# ==============================================================================
# Omnibus:                       13.561   Durbin-Watson:                   1.344
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               22.990
# Skew:                           0.398   Prob(JB):                     1.02e-05
# Kurtosis:                       4.598   Cond. No.                         50.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 9: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.120
# Model:                            OLS   Adj. R-squared:                  0.093
# Method:                 Least Squares   F-statistic:                     2.406
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):             0.0388
# Time:                        16:15:16   Log-Likelihood:                -80.232
# No. Observations:                 173   AIC:                             172.5
# Df Residuals:                     167   BIC:                             191.4
# Df Model:                           5
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.2821      0.135     -2.083      0.037      -0.548      -0.017
# France_News_Index     0.9441      0.310      3.047      0.002       0.337       1.551
# infl_fr               0.0108      0.088      0.122      0.903      -0.162       0.184
# infl_for_lt          -1.0896      0.832     -1.310      0.190      -2.719       0.540
# debt_gdp_fr           0.0211      0.020      1.080      0.280      -0.017       0.059
# VIX                  -0.6398      0.372     -1.719      0.086      -1.369       0.090
# ==============================================================================
# Omnibus:                        0.742   Durbin-Watson:                   0.735
# Prob(Omnibus):                  0.690   Jarque-Bera (JB):                0.860
# Skew:                           0.139   Prob(JB):                        0.650
# Kurtosis:                       2.795   Cond. No.                         50.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 10: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.160
# Model:                            OLS   Adj. R-squared:                  0.135
# Method:                 Least Squares   F-statistic:                     4.055
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):            0.00168
# Time:                        16:15:16   Log-Likelihood:                -36.875
# No. Observations:                 173   AIC:                             85.75
# Df Residuals:                     167   BIC:                             104.7
# Df Model:                           5
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.4963      0.103      4.796      0.000       0.293       0.699
# France_News_Index    -0.4021      0.173     -2.323      0.020      -0.741      -0.063
# infl_fr              -0.0874      0.091     -0.959      0.337      -0.266       0.091
# infl_for_lt          -0.6072      0.927     -0.655      0.512      -2.424       1.210
# debt_gdp_fr          -0.0009      0.020     -0.044      0.965      -0.039       0.038
# VIX                  -0.8574      0.241     -3.560      0.000      -1.329      -0.385
# ==============================================================================
# Omnibus:                        3.276   Durbin-Watson:                   0.749
# Prob(Omnibus):                  0.194   Jarque-Bera (JB):                2.817
# Skew:                          -0.264   Prob(JB):                        0.244
# Kurtosis:                       3.335   Cond. No.                         50.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.

# %% [markdown]
# On souhaite enfin publier les résultats joliment:

# %%
from statsmodels.iolib.summary2 import summary_col
import statsmodels.api as sm

regdata_all_diff_short=regdata_all_diff.copy()
regdata_all_diff_short=regdata_all_diff_short[regdata_all_diff_short.index>=np.datetime64("2017-05-01")]


def run_model(data, y_var, x_vars, robust=False):
    X = data[x_vars]
    X = sm.add_constant(X)
    Y = data[y_var]
    if robust:
        return sm.OLS(Y, X).fit(cov_type='HAC', cov_kwds={'maxlags': 1})
    else:
        return sm.OLS(Y, X).fit()

# Spécifications des variables
indep = ["France_News_Index"]
controls_r = ["infl_fr", "infl_for_lt", "debt_gdp_fr", "VIX"]
controls_f = ["deposit_rate", "infl_fr", "infl_for_lt", "euribor3", "debt_gdp_fr", "VIX"]
controls_signif=["infl_fr", "euribor3", "VIX"]
last=["euribor3"]
last2=["infl_fr", "euribor3","VIX"]

# Boucle sur tous les facteurs
models = []
model_names = []

for i in range(10):
    y = f"factor {i+1}"

    model1 = run_model(regdata_all, y, indep, robust=False)
    model2 = run_model(regdata_all, y, indep + controls_f, robust=False)
    model3 = run_model(regdata_all_diff, y, indep, robust=True)
    model4 = run_model(regdata_all_diff, y, indep + controls_f, robust=True)
    model5 = run_model(regdata_all_diff, y, indep + controls_r, robust=True)
    model6 = run_model(regdata_all_diff, y, indep + controls_signif, robust=True)
    model7 = run_model(regdata_all_diff_short, y, indep + controls_f, robust=True)
    model8=run_model(regdata_all_diff_short, y, indep + last, robust=True)
    model9=run_model(regdata_all, y, indep + last2, robust=True)

    #choix du modèle présenté
    models.append(model9)
    model_names.append(f"Facteur {i+1}")

# Création du tableau LaTeX avec 10 colonnes (un facteur par colonne, spécification 5 ici)
results_table = summary_col(models,
                            stars=True,
                            float_format='%0.3f',
                            model_names=model_names,
                            info_dict={'R²': lambda x: f"{x.rsquared:.2f}",
                                       'N': lambda x: f"{int(x.nobs)}"})

# Export LaTeX
with open("table_facteurs_spec9.tex", "w") as f:
    f.write(results_table.as_latex())

# %%
### On essaie enfin de faire les régressions sur une période plus courte, depuis le 1er mandat Macron:

regdata_all_diff_short=regdata_all_diff.copy()
regdata_all_diff_short=regdata_all_diff_short[regdata_all_diff_short.index>=np.datetime64("2017-05-01")]
    
independent = ["France_News_Index"]
restricted_controls=["infl_fr","infl_for_lt","debt_gdp_fr", "VIX"]
full_controls=["deposit_rate", "infl_fr","infl_for_lt","euribor3","debt_gdp_fr", "VIX"]

print("Période: à partir du 1er mai 2017")
for i in range(10):
    regression_diff(regdata_all_diff_short,i, independent, full_controls,robust=True,)
# Out:
# Période: à partir du 1er mai 2017
# #######################  Regression for factor 1: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.509
# Model:                            OLS   Adj. R-squared:                  0.467
# Method:                 Least Squares   F-statistic:                     14.27
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           6.12e-12
# Time:                        16:15:17   Log-Likelihood:                 61.246
# No. Observations:                  89   AIC:                            -106.5
# Df Residuals:                      81   BIC:                            -86.58
# Df Model:                           7
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.1037      0.053     -1.968      0.049      -0.207      -0.000
# France_News_Index     0.2264      0.126      1.793      0.073      -0.021       0.474
# deposit_rate         -0.0311      0.182     -0.171      0.864      -0.387       0.325
# infl_fr              -0.0376      0.036     -1.055      0.291      -0.108       0.032
# infl_for_lt           0.1806      0.506      0.357      0.721      -0.811       1.172
# euribor3              1.0098      0.336      3.008      0.003       0.352       1.668
# debt_gdp_fr           0.0046      0.006      0.758      0.449      -0.007       0.017
# VIX                   0.0022      0.085      0.026      0.979      -0.165       0.169
# ==============================================================================
# Omnibus:                        9.487   Durbin-Watson:                   1.724
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               12.278
# Skew:                           0.500   Prob(JB):                      0.00216
# Kurtosis:                       4.521   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 2: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.417
# Model:                            OLS   Adj. R-squared:                  0.367
# Method:                 Least Squares   F-statistic:                     5.993
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           1.22e-05
# Time:                        16:15:17   Log-Likelihood:                 40.648
# No. Observations:                  89   AIC:                            -65.30
# Df Residuals:                      81   BIC:                            -45.39
# Df Model:                           7
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.0473      0.064     -0.735      0.462      -0.174       0.079
# France_News_Index    -0.1036      0.140     -0.739      0.460      -0.378       0.171
# deposit_rate         -0.1781      0.180     -0.991      0.322      -0.530       0.174
# infl_fr               0.0199      0.037      0.541      0.588      -0.052       0.092
# infl_for_lt          -0.4340      0.416     -1.043      0.297      -1.249       0.381
# euribor3              1.2529      0.369      3.394      0.001       0.529       1.977
# debt_gdp_fr          -0.0066      0.006     -1.130      0.259      -0.018       0.005
# VIX                   0.2546      0.158      1.608      0.108      -0.056       0.565
# ==============================================================================
# Omnibus:                       36.441   Durbin-Watson:                   1.680
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              200.126
# Skew:                           1.058   Prob(JB):                     3.49e-44
# Kurtosis:                      10.035   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 3: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.132
# Model:                            OLS   Adj. R-squared:                  0.057
# Method:                 Least Squares   F-statistic:                     1.820
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):             0.0944
# Time:                        16:15:17   Log-Likelihood:                -11.035
# No. Observations:                  89   AIC:                             38.07
# Df Residuals:                      81   BIC:                             57.98
# Df Model:                           7
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.0865      0.096      0.904      0.366      -0.101       0.274
# France_News_Index    -0.5055      0.245     -2.061      0.039      -0.986      -0.025
# deposit_rate          0.0649      0.387      0.167      0.867      -0.695       0.824
# infl_fr               0.0856      0.094      0.908      0.364      -0.099       0.270
# infl_for_lt          -0.9884      1.233     -0.802      0.423      -3.404       1.427
# euribor3              0.4264      0.728      0.586      0.558      -1.000       1.853
# debt_gdp_fr          -0.0078      0.014     -0.573      0.567      -0.034       0.019
# VIX                   0.4879      0.289      1.685      0.092      -0.079       1.055
# ==============================================================================
# Omnibus:                       18.492   Durbin-Watson:                   1.697
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               61.290
# Skew:                          -0.511   Prob(JB):                     4.91e-14
# Kurtosis:                       6.935   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 4: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                 -0.020
# Method:                 Least Squares   F-statistic:                    0.8734
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):              0.531
# Time:                        16:15:17   Log-Likelihood:                 9.7333
# No. Observations:                  89   AIC:                            -3.467
# Df Residuals:                      81   BIC:                             16.44
# Df Model:                           7
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.0626      0.085     -0.738      0.460      -0.229       0.104
# France_News_Index     0.0011      0.168      0.006      0.995      -0.328       0.331
# deposit_rate          0.2293      0.210      1.094      0.274      -0.181       0.640
# infl_fr               0.0784      0.075      1.046      0.296      -0.068       0.225
# infl_for_lt           0.1613      1.262      0.128      0.898      -2.313       2.636
# euribor3             -0.4421      0.410     -1.078      0.281      -1.246       0.362
# debt_gdp_fr           0.0120      0.015      0.789      0.430      -0.018       0.042
# VIX                   0.2966      0.176      1.684      0.092      -0.049       0.642
# ==============================================================================
# Omnibus:                        8.726   Durbin-Watson:                   1.588
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):               10.066
# Skew:                           0.515   Prob(JB):                      0.00652
# Kurtosis:                       4.287   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 5: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.211
# Model:                            OLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                     2.582
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):             0.0187
# Time:                        16:15:17   Log-Likelihood:                 15.662
# No. Observations:                  89   AIC:                            -15.32
# Df Residuals:                      81   BIC:                             4.584
# Df Model:                           7
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.1204      0.089     -1.351      0.177      -0.295       0.054
# France_News_Index     0.0873      0.165      0.527      0.598      -0.237       0.412
# deposit_rate         -0.2886      0.215     -1.340      0.180      -0.710       0.133
# infl_fr               0.1186      0.059      2.023      0.043       0.004       0.234
# infl_for_lt          -0.2771      0.735     -0.377      0.706      -1.717       1.163
# euribor3              0.9551      0.423      2.257      0.024       0.126       1.784
# debt_gdp_fr          -0.0118      0.010     -1.194      0.232      -0.031       0.008
# VIX                   0.2419      0.179      1.349      0.177      -0.110       0.593
# ==============================================================================
# Omnibus:                        2.988   Durbin-Watson:                   1.629
# Prob(Omnibus):                  0.224   Jarque-Bera (JB):                2.284
# Skew:                           0.323   Prob(JB):                        0.319
# Kurtosis:                       3.446   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 6: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.181
# Model:                            OLS   Adj. R-squared:                  0.111
# Method:                 Least Squares   F-statistic:                     4.545
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           0.000256
# Time:                        16:15:17   Log-Likelihood:                 7.7596
# No. Observations:                  89   AIC:                            0.4807
# Df Residuals:                      81   BIC:                             20.39
# Df Model:                           7
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.1624      0.114     -1.430      0.153      -0.385       0.060
# France_News_Index    -0.1926      0.193     -0.997      0.319      -0.571       0.186
# deposit_rate          0.1310      0.208      0.630      0.529      -0.277       0.539
# infl_fr               0.0265      0.054      0.494      0.621      -0.079       0.131
# infl_for_lt          -0.9340      0.684     -1.365      0.172      -2.275       0.407
# euribor3              0.1588      0.331      0.479      0.632      -0.490       0.808
# debt_gdp_fr          -0.0064      0.008     -0.761      0.446      -0.023       0.010
# VIX                   0.7520      0.157      4.802      0.000       0.445       1.059
# ==============================================================================
# Omnibus:                        0.190   Durbin-Watson:                   1.247
# Prob(Omnibus):                  0.909   Jarque-Bera (JB):                0.285
# Skew:                           0.104   Prob(JB):                        0.867
# Kurtosis:                       2.817   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 7: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                    0.8132
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):              0.579
# Time:                        16:15:17   Log-Likelihood:               -0.50311
# No. Observations:                  89   AIC:                             17.01
# Df Residuals:                      81   BIC:                             36.92
# Df Model:                           7
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.2243      0.108     -2.076      0.038      -0.436      -0.013
# France_News_Index     0.3725      0.204      1.823      0.068      -0.028       0.773
# deposit_rate          0.0520      0.223      0.233      0.816      -0.386       0.490
# infl_fr               0.0967      0.081      1.201      0.230      -0.061       0.255
# infl_for_lt           1.1501      1.097      1.048      0.295      -1.000       3.300
# euribor3             -0.1545      0.493     -0.313      0.754      -1.122       0.813
# debt_gdp_fr           0.0166      0.017      0.984      0.325      -0.016       0.050
# VIX                   0.0505      0.231      0.219      0.827      -0.402       0.503
# ==============================================================================
# Omnibus:                        5.356   Durbin-Watson:                   1.140
# Prob(Omnibus):                  0.069   Jarque-Bera (JB):                4.873
# Skew:                          -0.421   Prob(JB):                       0.0875
# Kurtosis:                       3.778   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 8: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.270
# Model:                            OLS   Adj. R-squared:                  0.207
# Method:                 Least Squares   F-statistic:                     5.230
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           5.96e-05
# Time:                        16:15:17   Log-Likelihood:                -9.1908
# No. Observations:                  89   AIC:                             34.38
# Df Residuals:                      81   BIC:                             54.29
# Df Model:                           7
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.2142      0.141     -1.519      0.129      -0.491       0.062
# France_News_Index     0.4966      0.276      1.798      0.072      -0.045       1.038
# deposit_rate         -0.7104      0.236     -3.009      0.003      -1.173      -0.248
# infl_fr               0.0745      0.075      0.990      0.322      -0.073       0.222
# infl_for_lt          -1.0888      1.142     -0.953      0.340      -3.327       1.149
# euribor3              2.1329      0.464      4.599      0.000       1.224       3.042
# debt_gdp_fr           0.0055      0.014      0.385      0.700      -0.022       0.033
# VIX                  -0.1506      0.246     -0.613      0.540      -0.632       0.331
# ==============================================================================
# Omnibus:                        6.381   Durbin-Watson:                   1.178
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                5.724
# Skew:                           0.548   Prob(JB):                       0.0572
# Kurtosis:                       3.586   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 9: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.121
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     1.376
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):              0.227
# Time:                        16:15:17   Log-Likelihood:                -24.470
# No. Observations:                  89   AIC:                             64.94
# Df Residuals:                      81   BIC:                             84.85
# Df Model:                           7
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.4027      0.160     -2.513      0.012      -0.717      -0.089
# France_News_Index     0.6387      0.333      1.921      0.055      -0.013       1.290
# deposit_rate          0.6184      0.343      1.803      0.071      -0.054       1.290
# infl_fr              -0.0118      0.087     -0.136      0.892      -0.182       0.158
# infl_for_lt          -0.0725      0.865     -0.084      0.933      -1.769       1.624
# euribor3             -0.8261      0.730     -1.132      0.258      -2.257       0.605
# debt_gdp_fr           0.0154      0.015      0.993      0.321      -0.015       0.046
# VIX                   0.1413      0.324      0.436      0.663      -0.494       0.776
# ==============================================================================
# Omnibus:                        1.488   Durbin-Watson:                   0.737
# Prob(Omnibus):                  0.475   Jarque-Bera (JB):                0.914
# Skew:                          -0.167   Prob(JB):                        0.633
# Kurtosis:                       3.368   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.
# #######################  Regression for factor 10: #######################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.388
# Model:                            OLS   Adj. R-squared:                  0.335
# Method:                 Least Squares   F-statistic:                     9.406
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           1.74e-08
# Time:                        16:15:17   Log-Likelihood:                -15.963
# No. Observations:                  89   AIC:                             47.93
# Df Residuals:                      81   BIC:                             67.84
# Df Model:                           7
# Covariance Type:                  HAC
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.5639      0.123      4.571      0.000       0.322       0.806
# France_News_Index    -0.3002      0.262     -1.146      0.252      -0.814       0.213
# deposit_rate          0.3400      0.282      1.205      0.228      -0.213       0.893
# infl_fr              -0.0542      0.091     -0.595      0.552      -0.233       0.124
# infl_for_lt          -1.1737      1.007     -1.165      0.244      -3.148       0.801
# euribor3             -1.4107      0.469     -3.011      0.003      -2.329      -0.492
# debt_gdp_fr          -0.0232      0.016     -1.423      0.155      -0.055       0.009
# VIX                  -1.0942      0.228     -4.810      0.000      -1.540      -0.648
# ==============================================================================
# Omnibus:                        0.659   Durbin-Watson:                   0.716
# Prob(Omnibus):                  0.719   Jarque-Bera (JB):                0.788
# Skew:                          -0.172   Prob(JB):                        0.674
# Kurtosis:                       2.694   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Robust standard errors used.

# %% [markdown]
# ### Tests de l'impact dévénements

# %% [markdown]
# Chow test, Bai-Perron...

# %%
#on code une listd d'événements dont on souhaite étudier l'éffet sur nos séries

events_names=["COVID-19", "Ukraine War", "Brexit", "Trump Election", "Eurozone Crisis", "Greece Crisis 2", "Macron election 1", "Macron élection 2", "Dissolution", "Gilets Jaunes"]
events_dates=["2020-03-01", "2022-02-01", "2016-06-01", "2016-11-01", "2011-07-01", "2015-07-01", "2017-05-01", "2022-06-01", "2023-07-01", "2018-11-01"]
events_dates = pd.to_datetime(events_dates)
events_series = pd.Series(events_dates, index=events_names)

dates_regdata_all_diff= regdata_all_diff.index
dates_regdata_all_diff = pd.to_datetime(dates_regdata_all_diff)
dummys_events= pd.DataFrame(index=dates_regdata_all_diff, columns=events_names)

regdata_all_diff_dummys = regdata_all_diff.copy()


for i, col in enumerate(dummys_events.columns):
    dummys_events[col] = 0
    #all dates before the event are set to 0
    
    #all dates after the event are set to 1
    dummys_events.loc[events_series[col]<=dummys_events.index, col] = 1

    regdata_all_diff_dummys=pd.concat([regdata_all_diff_dummys, dummys_events], axis=1)



#on ajoute les variables dummies à nos données de régression
regdata_all_diff_dummys = pd.concat([regdata_all_diff.copy(), dummys_events])

controls_events=["deposit_rate", "infl_fr","infl_for_lt","euribor3","debt_gdp_fr", "VIX"]+events_names
independent = ["France_News_Index"]

regdata_all_diff_dummys.tail()
# Out:
#             factor 1  factor 2  factor 3  factor 4  factor 5  factor 6  \
# 2024-05-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2024-06-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2024-07-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2024-08-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2024-09-01       NaN       NaN       NaN       NaN       NaN       NaN
#
#             factor 7  factor 8  factor 9  factor 10  ...  COVID-19  \
# 2024-05-01       NaN       NaN       NaN        NaN  ...       1.0
# 2024-06-01       NaN       NaN       NaN        NaN  ...       1.0
# 2024-07-01       NaN       NaN       NaN        NaN  ...       1.0
# 2024-08-01       NaN       NaN       NaN        NaN  ...       1.0
# 2024-09-01       NaN       NaN       NaN        NaN  ...       1.0
#
#             Ukraine War  Brexit  Trump Election  Eurozone Crisis  \
# 2024-05-01          1.0     1.0             1.0              1.0
# 2024-06-01          1.0     1.0             1.0              1.0
# 2024-07-01          1.0     1.0             1.0              1.0
# 2024-08-01          1.0     1.0             1.0              1.0
# 2024-09-01          1.0     1.0             1.0              1.0
#
#             Greece Crisis 2  Macron election 1  Macron élection 2  \
# 2024-05-01              1.0                1.0                1.0
# 2024-06-01              1.0                1.0                1.0
# 2024-07-01              1.0                1.0                1.0
# 2024-08-01              1.0                1.0                1.0
# 2024-09-01              1.0                1.0                1.0
#
#             Dissolution  Gilets Jaunes
# 2024-05-01          1.0            1.0
# 2024-06-01          1.0            1.0
# 2024-07-01          1.0            1.0
# 2024-08-01          1.0            1.0
# 2024-09-01          1.0            1.0
#
# [5 rows x 32 columns]

# %%
for i in range(10):
    regression_diff(regdata_all_diff_dummys,i, independent, controls_events,robust=True,)
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# Cell In[43], line 2
#       1 for i in range(10):
# ----> 2     regression_diff(regdata_all_diff_dummys,i, independent, controls_events,robust=True,)
#
# Cell In[39], line 23, in regression_diff(data, factor, independent, controls, robust)
#      18 X = sm.add_constant(X)  # Adds a constant term to the predictor
#      21 if robust:
#      22     # Fit the model using HAC (Heteroskedasticity and Autocorrelation Consistent) standard errors
# ---> 23     model = sm.OLS(Y, X).fit(cov_type='HAC', cov_kwds={'maxlags': 1})
#      24 else:
#      25     model = sm.OLS(Y, X).fit()
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:921, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     918     msg = ("Weights are not supported in OLS and will be ignored"
#     919            "An exception will be raised in the next version.")
#     920     warnings.warn(msg, ValueWarning)
# --> 921 super().__init__(endog, exog, missing=missing,
#     922                           hasconst=hasconst, **kwargs)
#     923 if "weights" in self._init_keys:
#     924     self._init_keys.remove("weights")
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:746, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     744 else:
#     745     weights = weights.squeeze()
# --> 746 super().__init__(endog, exog, missing=missing,
#     747                           weights=weights, hasconst=hasconst, **kwargs)
#     748 nobs = self.exog.shape[0]
#     749 weights = self.weights
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:200, in RegressionModel.__init__(self, endog, exog, **kwargs)
#     199 def __init__(self, endog, exog, **kwargs):
# --> 200     super().__init__(endog, exog, **kwargs)
#     201     self.pinv_wexog: Float64Array | None = None
#     202     self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:270, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#     269 def __init__(self, endog, exog=None, **kwargs):
# --> 270     super().__init__(endog, exog, **kwargs)
#     271     self.initialize()
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:95, in Model.__init__(self, endog, exog, **kwargs)
#      93 missing = kwargs.pop('missing', 'none')
#      94 hasconst = kwargs.pop('hasconst', None)
# ---> 95 self.data = self._handle_data(endog, exog, missing, hasconst,
#      96                               **kwargs)
#      97 self.k_constant = self.data.k_constant
#      98 self.exog = self.data.exog
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:135, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     134 def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 135     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     136     # kwargs arrays could have changed, easier to just attach here
#     137     for key in kwargs:
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\data.py:675, in handle_data(endog, exog, missing, hasconst, **kwargs)
#     672     exog = np.asarray(exog)
#     674 klass = handle_data_class_factory(endog, exog)
# --> 675 return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     676              **kwargs)
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\data.py:88, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#      86 self.const_idx = None
#      87 self.k_constant = 0
# ---> 88 self._handle_constant(hasconst)
#      89 self._check_integrity()
#      90 self._cache = {}
#
# File c:\Users\mathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\data.py:134, in ModelData._handle_constant(self, hasconst)
#     132 exog_max = np.max(self.exog, axis=0)
#     133 if not np.isfinite(exog_max).all():
# --> 134     raise MissingDataError('exog contains inf or nans')
#     135 exog_min = np.min(self.exog, axis=0)
#     136 const_idx = np.where(exog_max == exog_min)[0].squeeze()
#
# MissingDataError: exog contains inf or nans

# %% [markdown]
# ### Statistiques descriptives (avant diff-diff)

# %%
from tabulate import tabulate

# %%
## Summary statistics of regression variables

data_summary = regdata_all.copy()


# Compute summary statistics
summary_stats = data_summary.describe().T

# Format for markdown or text reports
formatted_table = tabulate(summary_stats, headers="keys", tablefmt="github")

print(summary_stats.to_latex(index=True, float_format="%.3f", caption="Summary Statistics"))
# Out:
# \begin{table}
# \caption{Summary Statistics}
# \begin{tabular}{lrrrrrrrr}
# \toprule
#  & count & mean & std & min & 25% & 50% & 75% & max \\
# \midrule
# factor 1 & 173.000 & 0.398 & 1.552 & -0.791 & -0.458 & -0.192 & 0.364 & 5.317 \\
# factor 2 & 173.000 & 0.375 & 1.378 & -1.069 & -0.639 & -0.061 & 0.602 & 4.070 \\
# factor 3 & 173.000 & -0.064 & 1.123 & -1.484 & -0.979 & -0.449 & 0.722 & 2.661 \\
# factor 4 & 173.000 & 0.395 & 1.085 & -1.628 & -0.474 & 0.346 & 1.273 & 2.747 \\
# factor 5 & 173.000 & 1.477 & 1.684 & -1.018 & -0.006 & 1.023 & 3.076 & 5.099 \\
# factor 6 & 173.000 & -0.193 & 2.042 & -3.824 & -1.661 & -0.527 & 0.482 & 4.923 \\
# factor 7 & 173.000 & 4.313 & 1.929 & 0.619 & 3.074 & 4.305 & 5.724 & 8.359 \\
# factor 8 & 173.000 & 1.738 & 2.031 & -1.957 & 0.401 & 1.398 & 3.181 & 5.888 \\
# factor 9 & 173.000 & -0.525 & 2.754 & -4.948 & -2.682 & -0.618 & 1.298 & 5.585 \\
# factor 10 & 173.000 & 6.900 & 2.657 & 0.909 & 5.530 & 7.294 & 8.893 & 11.152 \\
# Month & 173.000 & 6.514 & 3.421 & 1.000 & 4.000 & 7.000 & 9.000 & 12.000 \\
# European_News_Index & 173.000 & 226.954 & 68.133 & 111.796 & 176.024 & 216.734 & 265.508 & 433.278 \\
# Germany_News_Index & 173.000 & 280.215 & 195.014 & 65.217 & 148.173 & 201.003 & 361.967 & 849.164 \\
# Italy_News_Index & 173.000 & 124.569 & 40.166 & 31.702 & 99.271 & 119.482 & 144.468 & 279.389 \\
# UK_News_Index & 173.000 & 300.316 & 139.343 & 111.099 & 205.929 & 267.985 & 374.768 & 1141.796 \\
# France_News_Index & 173.000 & 0.471 & 0.143 & 0.230 & 0.373 & 0.447 & 0.540 & 1.000 \\
# Spain_News_Index & 173.000 & 131.032 & 44.664 & 42.260 & 102.051 & 124.948 & 156.241 & 282.248 \\
# deposit_rate & 173.000 & -0.042 & 0.208 & -0.250 & -0.100 & -0.100 & -0.100 & 0.750 \\
# infl_fr & 173.000 & 1.973 & 1.801 & -0.400 & 0.800 & 1.600 & 2.400 & 7.300 \\
# infl_for_lt & 173.000 & 1.896 & 0.135 & 1.650 & 1.810 & 1.880 & 1.980 & 2.180 \\
# euribor3 & 173.000 & 0.491 & 1.273 & -0.582 & -0.329 & 0.005 & 0.859 & 3.972 \\
# debt_gdp_fr & 173.000 & 100.715 & 8.998 & 85.939 & 94.558 & 99.082 & 111.320 & 117.687 \\
# VIX & 173.000 & 0.318 & 0.113 & 0.175 & 0.242 & 0.291 & 0.364 & 1.000 \\
# factor1_lagged & 173.000 & 0.375 & 1.520 & -0.791 & -0.458 & -0.192 & 0.364 & 5.317 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
## plot nice tables for full data:

list_BCE_data_copy_tables = [data.copy() for data in list_BCE_data]
#list_BCE_data_copy_tables.append(data_NB.copy())
list_BCE_data_copy_tables.append(data_factors.copy())
data_summary = pd.concat(list_BCE_data_copy_tables, axis=1)
data_summary=data_summary[data_summary.index>=np.datetime64("2009-12-01")]

#data_summary.drop(["Germany_News_Index", "Italy_News_Index", "Spain_News_Index", "UK_News_Index"],axis=1, inplace=True)


# Compute summary statistics
summary_stats = data_summary.describe().T

# Add columns for minimum and maximum dates for each data
summary_stats['min_date'] = data_summary.apply(lambda col: col.dropna().index.min().date() if col.dropna().index.is_unique else None, axis=0)
summary_stats['max_date'] = data_summary.apply(lambda col: col.dropna().index.max().date() if col.dropna().index.is_unique else None, axis=0)

# Add a frequency column
summary_stats['frequency'] = data_summary.apply(lambda col: col.dropna().index.freqstr if col.dropna().index.freq else 'Unknown', axis=0)


# Add autocorrelation column
summary_stats['autocorrelation'] = data_summary.apply(
    lambda col: col[~data_summary.duplicated()].dropna().autocorr() if col.dtype in [np.float64, np.int64] else None, axis=0
)

# Format for markdown or text reports
formatted_table = tabulate(summary_stats, headers="keys", tablefmt="github")


print(summary_stats.to_latex(index=True, float_format="%.3f", caption="Summary Statistics with Min, Max Dates, and Frequency"))
# Out:
# \begin{table}
# \caption{Summary Statistics with Min, Max Dates, and Frequency}
# \begin{tabular}{lrrrrrrrrlllr}
# \toprule
#  & count & mean & std & min & 25% & 50% & 75% & max & min_date & max_date & frequency & autocorrelation \\
# \midrule
# deposit_rate & 5588.000 & -0.055 & 0.206 & -0.250 & -0.100 & -0.100 & -0.100 & 0.750 & 2009-12-01 & 2025-03-19 & Unknown & 0.983 \\
# infl_fr & 183.000 & 1.944 & 1.756 & -0.400 & 0.800 & 1.600 & 2.400 & 7.300 & 2009-12-31 & 2025-02-28 & Unknown & 0.981 \\
# infl_for_lt & 62.000 & 1.900 & 0.132 & 1.650 & 1.820 & 1.890 & 1.988 & 2.180 & 2009-12-31 & 2025-03-31 & Unknown & 0.948 \\
# euribor3 & 183.000 & 0.576 & 1.314 & -0.582 & -0.329 & 0.081 & 1.004 & 3.972 & 2009-12-31 & 2025-02-28 & Unknown & 0.997 \\
# debt_gdp_fr & 60.000 & 100.574 & 9.354 & 84.056 & 94.461 & 99.011 & 111.344 & 117.687 & 2009-12-31 & 2024-09-30 & Unknown & 0.975 \\
# factor 1 & 772.000 & 0.386 & 1.515 & -0.936 & -0.456 & -0.174 & 0.400 & 5.705 & 2009-12-02 & 2024-09-11 & Unknown & 0.998 \\
# factor 2 & 772.000 & 0.376 & 1.355 & -1.094 & -0.621 & -0.046 & 0.689 & 4.164 & 2009-12-02 & 2024-09-11 & Unknown & 0.998 \\
# factor 3 & 772.000 & -0.040 & 1.127 & -1.544 & -0.973 & -0.416 & 0.796 & 3.445 & 2009-12-02 & 2024-09-11 & Unknown & 0.990 \\
# factor 4 & 772.000 & 0.443 & 1.121 & -1.788 & -0.458 & 0.347 & 1.323 & 3.059 & 2009-12-02 & 2024-09-11 & Unknown & 0.992 \\
# factor 5 & 772.000 & 1.551 & 1.722 & -1.079 & 0.066 & 1.062 & 3.188 & 5.489 & 2009-12-02 & 2024-09-11 & Unknown & 0.996 \\
# factor 6 & 772.000 & -0.080 & 2.122 & -3.870 & -1.705 & -0.441 & 0.718 & 5.182 & 2009-12-02 & 2024-09-11 & Unknown & 0.998 \\
# factor 7 & 772.000 & 4.362 & 1.922 & 0.306 & 3.071 & 4.372 & 5.778 & 8.472 & 2009-12-02 & 2024-09-11 & Unknown & 0.997 \\
# factor 8 & 772.000 & 1.765 & 2.009 & -2.000 & 0.354 & 1.458 & 3.165 & 6.197 & 2009-12-02 & 2024-09-11 & Unknown & 0.997 \\
# factor 9 & 772.000 & -0.389 & 2.819 & -5.026 & -2.590 & -0.513 & 1.557 & 5.685 & 2009-12-02 & 2024-09-11 & Unknown & 0.999 \\
# factor 10 & 772.000 & 6.727 & 2.808 & 0.092 & 5.160 & 7.055 & 8.868 & 11.246 & 2009-12-02 & 2024-09-11 & Unknown & 0.999 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
for data in list_BCE_data:
    print(data.head())
# Out:
#             deposit_rate
# Date
# 1999-01-01           NaN
# 1999-01-04          0.75
# 1999-01-05          0.75
# 1999-01-06          0.75
# 1999-01-07          0.75
#             infl_fr
# Date
# 1997-01-31      1.8
# 1997-02-28      1.7
# 1997-03-31      1.1
# 1997-04-30      1.0
# 1997-05-31      0.9
#             infl_for_lt
# Date
# 1999-03-31         1.86
# 2000-03-31         1.77
# 2001-03-31         1.81
# 2001-06-30         1.80
# 2001-09-30         1.81
#             euribor3
# Date
# 1994-01-31      6.91
# 1994-02-28      6.86
# 1994-03-31      6.75
# 1994-04-30      6.57
# 1994-05-31      6.24
#             debt_gdp_fr
# Date
# 1999-03-31       60.228
# 1999-06-30       59.523
# 1999-09-30       59.731
# 1999-12-31       59.062
# 2000-03-31       60.377

# %% [markdown]
# ### Présentation résultats régressions
